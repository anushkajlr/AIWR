# %% [markdown]
# # 1. PREPROCESSING THE DATA

# %% [markdown]
# ## IMPORTING REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv("ratings.csv",index_col = "Unnamed: 0")
# Out:
# C:\Users\anush\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
dataframe.shape
# Out:
# (1319968, 3)

# %% [markdown]
# ## DROPPING THE RATING COLUMN

# %%
dataframe = dataframe.drop(['rating'], axis=1)

# %% [markdown]
# ## TREATING SAME RESTAURANT AT DIFFERENT LOCATIONS AS ONE ENTITY TO REDUCE SIZE OF POSTING LIST IN LATER IMPLEMENTATIONS

# %%
dataframe['review'] = dataframe[['name','review']].groupby(['name'])['review'].transform(lambda x: ''.join(str(x)))

# %%
dataframe.shape
# Out:
# (1319968, 2)

# %% [markdown]
# ## DELETING ALL DUPLICATE COLUMNS

# %%
dataframe = dataframe[['name','review']].drop_duplicates()

# %%
dataframe.shape
# Out:
# (7041, 2)

# %%
dataframe
# Out:
#                                                       name  \
# 0                                                    Jalsa
# 12                                          Spice Elephant
# 26                                         San Churro Cafe
# 46                                   Addhuri Udupi Bhojana
# 81                                           Grand Village
# ...                                                    ...
# 1315206                        Calcutta North Indian Meals
# 1315268  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 1315289                       The Nest - The Den Bengaluru
# 1315306                                      Nawabs Empire
# 1315570                                   SeeYa Restaurant
#
#                                                     review
# 0        0          A beautiful place to dine inThe int...
# 12       12       Had been here for dinner with family ...
# 26       26        Ambience is not that good enough and...
# 46       46       Great food and proper Karnataka style...
# 81       81       Very good restaurant in neighbourhood...
# ...                                                    ...
# 1315206  1315206    This center probably famous for nam...
# 1315268  1315268    Nice and friendly place and staff i...
# 1315289  1315289    Great ambience  looking nice good s...
# 1315306  1315306    This place is not at all good We ha...
# 1315570  1315570    Good food take bit time to get the ...
#
# [7041 rows x 2 columns]

# %% [markdown]
# ## MAKING ALL STRINGS LOWER CASE

# %%
dataframe['review'] = dataframe['review'].str.lower()

# %% [markdown]
# ## REMOVING ERRONEOUS NUMBERS FROM THE REVIEWS

# %%
dataframe.review = dataframe.review.str.replace('\d+', '')
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_23760\3252944537.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe.review = dataframe.review.str.replace('\d+', '')

# %% [markdown]
# ## REMOVING STOP WORDS

# %%
import nltk.corpus
stop = nltk.corpus.stopwords.words('english')

# %%
dataframe['review'] = dataframe['review'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %% [markdown]
# ## ONLY KEEPING WORDS PRESENT IN THE ENGLISH DICTIONARY

# %%
words = set(nltk.corpus.words.words())

# %%
dataframe['review'] = dataframe['review'].apply(lambda x: ' '.join([word for word in x.split() if word in (words)]))

# %%
dataframe
# Out:
#                                                       name  \
# 0                                                    Jalsa
# 12                                          Spice Elephant
# 26                                         San Churro Cafe
# 46                                   Addhuri Udupi Bhojana
# 81                                           Grand Village
# ...                                                    ...
# 1315206                        Calcutta North Indian Meals
# 1315268  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 1315289                       The Nest - The Den Bengaluru
# 1315306                                      Nawabs Empire
# 1315570                                   SeeYa Restaurant
#
#                                                     review
# 0        beautiful place dine dinner family restaurant ...
# 12       dinner family turned ambience really nice staf...
# 26       ambience good enough went quick bite first big...
# 46       great food proper style full place half good f...
# 81       good restaurant buffet great service overwhelm...
# ...                                                    ...
# 1315206                center probably famous north object
# 1315268  nice friendly place staff awesome service bad ...
# 1315289  great ambience looking nice good selection nes...
# 1315306    place good ordered negative review would object
# 1315570  good food take bit time get food coz ordered c...
#
# [7041 rows x 2 columns]

# %% [markdown]
# ## RESETING INDEX

# %%
dataframe.reset_index(drop=True, inplace = True)

# %%
import nltk

# %% [markdown]
# ## LEMMETIZING WITHOUT POS INDEX

# %%
# import nltk

# w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
# lemmatizer = nltk.stem.WordNetLemmatizer()

# def lemmatize_text(text):
#     return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]


# dataframe['review'] = dataframe.review.apply(lemmatize_text)

# %%
dataframe
# Out:
#                                                    name  \
# 0                                                 Jalsa
# 1                                        Spice Elephant
# 2                                       San Churro Cafe
# 3                                 Addhuri Udupi Bhojana
# 4                                         Grand Village
# ...                                                 ...
# 7036                        Calcutta North Indian Meals
# 7037  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 7038                       The Nest - The Den Bengaluru
# 7039                                      Nawabs Empire
# 7040                                   SeeYa Restaurant
#
#                                                  review
# 0     beautiful place dine dinner family restaurant ...
# 1     dinner family turned ambience really nice staf...
# 2     ambience good enough went quick bite first big...
# 3     great food proper style full place half good f...
# 4     good restaurant buffet great service overwhelm...
# ...                                                 ...
# 7036                center probably famous north object
# 7037  nice friendly place staff awesome service bad ...
# 7038  great ambience looking nice good selection nes...
# 7039    place good ordered negative review would object
# 7040  good food take bit time get food coz ordered c...
#
# [7041 rows x 2 columns]

# %% [markdown]
# ## Words like friendly do not get converted so lemmetizing with POS tag

# %% [markdown]
# ## LEMMETIZING WITH POS TAG

# %% [markdown]
# SIZE OF DICTIONARY BEFORE LEMMETIZATION

# %%
d = set()
for words in dataframe.review.str.findall(r"\w+").map(set):
    for word in words:
        d.add(word)
print(len(d))
# Out:
# 4889

# %%
# WORDNET LEMMATIZER (with appropriate pos tags)

import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()

def pos_tagger(nltk_tag):
	if nltk_tag.startswith('J'):
		return wordnet.ADJ
	elif nltk_tag.startswith('V'):
		return wordnet.VERB
	elif nltk_tag.startswith('N'):
		return wordnet.NOUN
	elif nltk_tag.startswith('R'):
		return wordnet.ADV
	else:		
		return None

def pos_tagged(sentence):
    return nltk.pos_tag(nltk.word_tokenize(sentence))

def wordnet_tagged(sentence):
    return list(map(lambda x: (x[0], pos_tagger(x[1])), sentence))

def lem(sentence):
    lemmatized_sentence = []
    for word, tag in sentence:
        if tag is None:
            # if there is no available tag, append the token as is
            lemmatized_sentence.append(word)
        else:	
            # else use the tag to lemmatize the token
            lemmatized_sentence.append(lemmatizer.lemmatize(word, tag))
    return " ".join(lemmatized_sentence)


def final(sentence):
    sentence = pos_tagged(sentence)
    sentence = wordnet_tagged(sentence)
    sentence = lem(sentence)
    return sentence
    
dataframe['review'] = dataframe['review'].apply(final)
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [WinError 10054] An existing connection was forcibly
# [nltk_data]     closed by the remote host>

# %%
dataframe
# Out:
#                                                    name  \
# 0                                                 Jalsa
# 1                                        Spice Elephant
# 2                                       San Churro Cafe
# 3                                 Addhuri Udupi Bhojana
# 4                                         Grand Village
# ...                                                 ...
# 7036                        Calcutta North Indian Meals
# 7037  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 7038                       The Nest - The Den Bengaluru
# 7039                                      Nawabs Empire
# 7040                                   SeeYa Restaurant
#
#                                                  review
# 0     beautiful place dine dinner family restaurant ...
# 1     dinner family turn ambience really nice staff ...
# 2     ambience good enough go quick bite first big t...
# 3     great food proper style full place half good f...
# 4     good restaurant buffet great service overwhelm...
# ...                                                 ...
# 7036                center probably famous north object
# 7037  nice friendly place staff awesome service bad ...
# 7038  great ambience look nice good selection nest o...
# 7039      place good order negative review would object
# 7040  good food take bit time get food coz order chi...
#
# [7041 rows x 2 columns]

# %%
#estimating the size of the dictionary AFTER LEMMETIZATION

d = set()
for words in dataframe.review.str.findall(r"\w+").map(set):
    for word in words:
        d.add(word)
print(len(d))
# Out:
# 4633

# %%
#4889 to 4633 is the length of the dictionary after lemmetization

# %%
#trying to compress posting list by using docid instead

# %% [markdown]
# ## 2.  CREATING INVERTED INDEX

# %%
new_list = []
for i in range(dataframe.shape[0]):
    for j in dataframe.iloc[i,1].split():
        new_list.append([j,i])
new_list = sorted(new_list)
dict_index = {}
words = []
for i in new_list:
    if i[0] not in words:
        words.append(i[0])
        dict_index[i[0]] = [1,[i[1]]]
    else:  
        if(i[1] not in dict_index[i[0]][1]):    
            dict_index[i[0]][0]+=1
            dict_index[i[0]][1].append(i[1])

# %%
dict_index
# Out:
# {'aa': [3, [3925, 5024, 6230]],
#  'abandon': [1, [1241]],
#  'able': [12,
#   [736, 815, 1645, 1902, 2228, 4302, 5089, 6007, 6016, 6474, 6657, 6737]],
#  'absolute': [33,
#   [234,
#    503,
#    560,
#    767,
#    768,
#    1018,
#    1020,
#    1080,
#    1508,
#    1581,
#    1673,
#    1774,
#    1983,
#    2068,
#    2206,
#    2225,
#    2601,
#    2682,
#    2783,
#    3085,
#    3647,
#    3915,
#    3991,
#    4172,
#    4849,
#    5228,
#    5251,
#    5383,
#    5426,
#    5974,
#    6029,
#    6100,
#    6604]],
#  'absolutely': [166,
#   [51,
#    66,
#    109,
#    145,
#    147,
#    155,
#    191,
#    204,
#    436,
#    498,
#    506,
#    610,
#    658,
#    660,
#    697,
#    706,
#    739,
#    763,
#    775,
#    859,
#    936,
#    953,
#    1019,
#    1031,
#    1191,
#    1288,
#    1331,
#    1466,
#    1555,
#    1575,
#    1662,
#    1677,
#    1728,
#    1825,
#    1855,
#    1876,
#    1976,
#    1983,
#    1996,
#    2020,
#    2039,
#    2053,
#    2058,
#    2133,
#    2153,
#    2168,
#    2189,
#    2192,
#    2193,
#    2199,
#    2250,
#    2253,
#    2302,
#    2318,
#    2332,
#    2339,
#    2442,
#    2489,
#    2526,
#    2528,
#    2537,
#    2569,
#    2575,
#    2590,
#    2721,
#    2856,
#    2866,
#    2871,
#    2875,
#    2927,
#    2988,
#    3007,
#    3031,
#    3160,
#    3162,
#    3277,
#    3281,
#    3404,
#    3446,
#    3468,
#    3521,
#    3550,
#    3570,
#    3574,
#    3611,
#    3673,
#    3687,
#    3733,
#    3775,
#    3780,
#    3846,
#    3873,
#    4011,
#    4017,
#    4077,
#    4108,
#    4177,
#    4187,
#    4245,
#    4263,
#    4347,
#    4355,
#    4380,
#    4434,
#    4493,
#    4576,
#    4584,
#    4591,
#    4603,
#    4610,
#    4631,
#    4641,
#    4702,
#    4703,
#    4718,
#    4827,
#    4876,
#    4886,
#    4912,
#    4957,
#    4983,
#    5010,
#    5035,
#    5073,
#    5113,
#    5161,
#    5180,
#    5211,
#    5216,
#    5228,
#    5230,
#    5237,
#    5264,
#    5299,
#    5345,
#    5357,
#    5364,
#    5463,
#    5476,
#    5501,
#    5533,
#    5534,
#    5579,
#    5648,
#    5682,
#    5742,
#    5757,
#    5774,
#    5785,
#    5813,
#    5832,
#    5896,
#    5977,
#    5978,
#    6042,
#    6069,
#    6144,
#    6310,
#    6324,
#    6334,
#    6443,
#    6545,
#    6590,
#    6729,
#    6784,
#    6953]],
#  'abstract': [1, [1533]],
#  'abundance': [1, [5527]],
#  'abusive': [1, [3729]],
#  'abysmal': [2, [3168, 5437]],
#  'accept': [18,
#   [739,
#    859,
#    969,
#    1498,
#    1577,
#    1945,
#    2255,
#    2428,
#    2757,
#    2831,
#    2843,
#    3724,
#    4253,
#    4646,
#    4760,
#    5471,
#    6148,
#    6732]],
#  'acceptable': [3, [1015, 4120, 5215]],
#  'access': [7, [586, 1123, 2584, 3488, 4568, 5840, 6845]],
#  'accessibility': [1, [1712]],
#  'accessible': [6, [30, 284, 405, 2208, 3725, 5487]],
#  'accident': [6, [548, 685, 3474, 5045, 5096, 5674]],
#  'accidental': [5, [1790, 2040, 3528, 5347, 5716]],
#  'accidentally': [8, [564, 1068, 1215, 1423, 2617, 5507, 6653, 6745]],
#  'accidently': [4, [2398, 4696, 4737, 5725]],
#  'accommodate': [1, [4197]],
#  'accompaniment': [1, [1585]],
#  'accord': [12,
#   [202, 221, 335, 598, 791, 1727, 3394, 4227, 4458, 5361, 6436, 6449]],
#  'account': [5, [2845, 3275, 5943, 6286, 6590]],
#  'accurate': [1, [569]],
#  'ache': [1, [1943]],
#  'acronym': [1, [4705]],
#  'across': [59,
#   [267,
#    623,
#    941,
#    1068,
#    1114,
#    1149,
#    1378,
#    1530,
#    1531,
#    1602,
#    2063,
#    2165,
#    2358,
#    2433,
#    2593,
#    2697,
#    2715,
#    2871,
#    2940,
#    3331,
#    3428,
#    3511,
#    3601,
#    3682,
#    3684,
#    3729,
#    3822,
#    3884,
#    4026,
#    4031,
#    4065,
#    4277,
#    4359,
#    4391,
#    4430,
#    4484,
#    4541,
#    4604,
#    4702,
#    4745,
#    4895,
#    4937,
#    4995,
#    5072,
#    5204,
#    5413,
#    5425,
#    5489,
#    5560,
#    5649,
#    5800,
#    5886,
#    6310,
#    6457,
#    6471,
#    6516,
#    6562,
#    6911,
#    6966]],
#  'act': [1, [303]],
#  'active': [1, [6329]],
#  'actual': [10, [192, 3010, 3692, 3839, 3849, 4057, 4392, 5159, 5433, 5613]],
#  'actually': [74,
#   [13,
#    67,
#    81,
#    401,
#    494,
#    701,
#    709,
#    980,
#    1028,
#    1279,
#    1306,
#    1510,
#    1526,
#    1574,
#    1668,
#    1734,
#    1808,
#    1901,
#    2190,
#    2226,
#    2243,
#    2364,
#    2516,
#    2761,
#    2775,
#    2893,
#    2934,
#    2963,
#    2986,
#    3054,
#    3069,
#    3092,
#    3187,
#    3206,
#    3243,
#    3301,
#    3316,
#    3352,
#    3434,
#    3476,
#    3643,
#    3656,
#    3780,
#    3785,
#    3983,
#    4072,
#    4554,
#    4628,
#    4650,
#    4759,
#    4780,
#    4792,
#    4822,
#    4853,
#    4854,
#    4920,
#    5038,
#    5052,
#    5239,
#    5464,
#    5476,
#    5964,
#    5995,
#    6041,
#    6145,
#    6237,
#    6408,
#    6501,
#    6561,
#    6682,
#    6748,
#    6753,
#    6770,
#    6855]],
#  'acute': [1, [5776]],
#  'ad': [3, [664, 3687, 4621]],
#  'adage': [1, [5859]],
#  'add': [44,
#   [33,
#    60,
#    116,
#    155,
#    222,
#    283,
#    302,
#    445,
#    571,
#    629,
#    686,
#    791,
#    866,
#    892,
#    1545,
#    1746,
#    1922,
#    2298,
#    2440,
#    2522,
#    2721,
#    2787,
#    2944,
#    3015,
#    3033,
#    3043,
#    3095,
#    3550,
#    3596,
#    3844,
#    4200,
#    4500,
#    4839,
#    5102,
#    5224,
#    5398,
#    5502,
#    6523,
#    6544,
#    6594,
#    6646,
#    6657,
#    6952,
#    6953]],
#  'adda': [23,
#   [141,
#    391,
#    1225,
#    1336,
#    1455,
#    2091,
#    2424,
#    2455,
#    2576,
#    2861,
#    3365,
#    3376,
#    4009,
#    4045,
#    4322,
#    4458,
#    5211,
#    5554,
#    5714,
#    5834,
#    5960,
#    6066,
#    6457]],
#  'added': [1, [929]],
#  'addict': [5, [2486, 4529, 4635, 4816, 6860]],
#  'addicted': [1, [1831]],
#  'addiction': [1, [978]],
#  'addition': [19,
#   [152,
#    411,
#    713,
#    1111,
#    2172,
#    2538,
#    3317,
#    4022,
#    4633,
#    5274,
#    5343,
#    5469,
#    5491,
#    5804,
#    5954,
#    6034,
#    6335,
#    6443,
#    6518]],
#  'address': [12,
#   [292, 931, 950, 1367, 2431, 3881, 3982, 5088, 5102, 5128, 6383, 6800]],
#  'adequate': [5, [1353, 2411, 2691, 4305, 5694]],
#  'adjacent': [4, [1511, 1566, 2727, 5229]],
#  'adjoin': [1, [197]],
#  'adjoining': [1, [1517]],
#  'adjustable': [1, [5773]],
#  'admirer': [1, [2395]],
#  'admit': [3, [3414, 4308, 4792]],
#  'adopt': [1, [5867]],
#  'adorable': [5, [273, 1258, 3189, 4543, 5231]],
#  'adore': [5, [189, 1956, 2537, 4631, 4872]],
#  'adventurous': [1, [305]],
#  'advert': [1, [1056]],
#  'advice': [2, [642, 2684]],
#  'advise': [2, [3296, 3564]],
#  'aegis': [1, [6984]],
#  'aesthetic': [4, [141, 1255, 2193, 3567]],
#  'aesthetically': [1, [6031]],
#  'affair': [5, [1889, 3673, 4493, 5183, 5914]],
#  'ago': [46,
#   [336,
#    345,
#    353,
#    477,
#    896,
#    1736,
#    1820,
#    1825,
#    2020,
#    2035,
#    2036,
#    2332,
#    2375,
#    2403,
#    2444,
#    2536,
#    2659,
#    2894,
#    2999,
#    3240,
#    3290,
#    3549,
#    3810,
#    3838,
#    3962,
#    4221,
#    4259,
#    4526,
#    4722,
#    4892,
#    5034,
#    5168,
#    5265,
#    5363,
#    5646,
#    5669,
#    5807,
#    5914,
#    5937,
#    6262,
#    6289,
#    6296,
#    6307,
#    6657,
#    6716,
#    6756]],
#  'agree': [8, [589, 1239, 1393, 1633, 2563, 5575, 6170, 6561]],
#  'ah': [3, [1258, 2285, 2530]],
#  'aha': [1, [1145]],
#  'ahead': [3, [1200, 1244, 4345]],
#  'aide': [1, [6592]],
#  'aiming': [1, [4714]],
#  'aint': [2, [3221, 5881]],
#  'air': [17,
#   [7,
#    649,
#    1240,
#    1765,
#    1978,
#    2407,
#    2483,
#    2506,
#    3678,
#    3874,
#    4674,
#    5285,
#    5423,
#    5523,
#    5917,
#    6430,
#    6976]],
#  'airport': [3, [1523, 4853, 5139]],
#  'airy': [4, [535, 1702, 3249, 5051]],
#  'aisle': [1, [5643]],
#  'aka': [3, [2648, 4613, 6066]],
#  'akhrot': [1, [6445]],
#  'al': [28,
#   [19,
#    127,
#    550,
#    1568,
#    1647,
#    1858,
#    1887,
#    2001,
#    2224,
#    2434,
#    2578,
#    2794,
#    2856,
#    3564,
#    3815,
#    4485,
#    4776,
#    5360,
#    5386,
#    5497,
#    5562,
#    5596,
#    5673,
#    5690,
#    5830,
#    6596,
#    6664,
#    6678]],
#  'ala': [2, [1663, 4017]],
#  'alba': [2, [2542, 2588]],
#  'albeit': [2, [3099, 5275]],
#  'alchemy': [2, [1256, 2479]],
#  'alcohol': [10, [990, 1240, 3980, 4294, 5176, 6149, 6229, 6376, 6447, 6708]],
#  'alcoholic': [1, [3246]],
#  'alert': [5, [2505, 2551, 3594, 4094, 5411]],
#  'alfa': [1, [1407]],
#  'alfresco': [1, [6235]],
#  'alibi': [1, [2602]],
#  'alif': [1, [780]],
#  'alive': [1, [1979]],
#  'allergic': [4, [101, 119, 3491, 6057]],
#  'alley': [5, [3046, 3092, 4280, 4524, 6473]],
#  'alliance': [1, [4303]],
#  'allow': [1, [3516]],
#  'allure': [2, [2726, 4841]],
#  'almond': [13,
#   [134,
#    773,
#    1541,
#    1718,
#    1783,
#    1824,
#    2854,
#    3572,
#    4108,
#    4788,
#    4816,
#    5015,
#    6470]],
#  'almost': [122,
#   [1,
#    56,
#    82,
#    84,
#    106,
#    190,
#    209,
#    210,
#    229,
#    281,
#    314,
#    331,
#    399,
#    423,
#    430,
#    497,
#    523,
#    529,
#    594,
#    626,
#    696,
#    788,
#    819,
#    825,
#    838,
#    1216,
#    1325,
#    1403,
#    1455,
#    1490,
#    1670,
#    1709,
#    1734,
#    1762,
#    1932,
#    2176,
#    2177,
#    2313,
#    2346,
#    2352,
#    2362,
#    2364,
#    2387,
#    2400,
#    2474,
#    2508,
#    2529,
#    2553,
#    2660,
#    2678,
#    2695,
#    2712,
#    2732,
#    2741,
#    2790,
#    2864,
#    2876,
#    2885,
#    2913,
#    2920,
#    2932,
#    3069,
#    3132,
#    3206,
#    3261,
#    3298,
#    3305,
#    3365,
#    3377,
#    3404,
#    3523,
#    3549,
#    3620,
#    3689,
#    3820,
#    3932,
#    4008,
#    4177,
#    4281,
#    4434,
#    4440,
#    4503,
#    4647,
#    4722,
#    4792,
#    4826,
#    4895,
#    4932,
#    5048,
#    5138,
#    5146,
#    5153,
#    5215,
#    5332,
#    5338,
#    5401,
#    5441,
#    5620,
#    5754,
#    5766,
#    5818,
#    5848,
#    6001,
#    6035,
#    6158,
#    6248,
#    6275,
#    6288,
#    6302,
#    6408,
#    6430,
#    6446,
#    6512,
#    6516,
#    6578,
#    6579,
#    6595,
#    6602,
#    6678,
#    6680,
#    6890,
#    6903]],
#  'alo': [2, [1303, 2474]],
#  'aloe': [2, [3900, 6899]],
#  'aloft': [6, [1496, 1505, 6990, 6993, 7011, 7012]],
#  'alone': [10, [24, 240, 911, 2536, 3268, 3652, 4021, 5695, 6293, 6991]],
#  'along': [57,
#   [79,
#    161,
#    230,
#    285,
#    304,
#    403,
#    412,
#    423,
#    579,
#    1081,
#    1097,
#    1125,
#    1293,
#    1465,
#    1528,
#    1579,
#    1585,
#    1600,
#    1609,
#    1640,
#    2062,
#    2500,
#    2571,
#    2727,
#    2741,
#    2981,
#    3212,
#    3240,
#    3259,
#    3262,
#    3307,
#    3368,
#    3441,
#    3455,
#    3525,
#    3695,
#    4209,
#    4230,
#    4319,
#    4527,
#    4643,
#    4809,
#    4863,
#    5159,
#    5433,
#    5537,
#    5743,
#    5799,
#    5992,
#    6180,
#    6196,
#    6355,
#    6376,
#    6788,
#    6863,
#    6953,
#    6978]],
#  'alongside': [3, [2080, 3245, 3273]],
#  'alpha': [1, [2768]],
#  'already': [18,
#   [350,
#    1849,
#    2250,
#    2708,
#    2710,
#    3052,
#    3167,
#    3534,
#    4451,
#    4529,
#    4713,
#    4848,
#    5035,
#    5163,
#    5342,
#    6154,
#    6443,
#    6609]],
#  'alright': [11,
#   [525, 665, 920, 1012, 1457, 1481, 1609, 1806, 3239, 4761, 6887]],
#  'also': [213,
#   [52,
#    74,
#    87,
#    118,
#    151,
#    154,
#    197,
#    205,
#    248,
#    256,
#    343,
#    359,
#    364,
#    433,
#    438,
#    484,
#    499,
#    552,
#    589,
#    671,
#    694,
#    702,
#    722,
#    729,
#    765,
#    841,
#    863,
#    880,
#    892,
#    913,
#    929,
#    939,
#    976,
#    1006,
#    1022,
#    1056,
#    1088,
#    1130,
#    1157,
#    1176,
#    1216,
#    1219,
#    1244,
#    1264,
#    1268,
#    1281,
#    1291,
#    1305,
#    1441,
#    1457,
#    1497,
#    1501,
#    1588,
#    1604,
#    1650,
#    1671,
#    1683,
#    1684,
#    1702,
#    1735,
#    1772,
#    1814,
#    1827,
#    1849,
#    1861,
#    1862,
#    1914,
#    1965,
#    1997,
#    6321,
#    6322,
#    6323,
#    6335,
#    6353,
#    6355,
#    6358,
#    6375,
#    6442,
#    6443,
#    6444,
#    6446,
#    6448,
#    6454,
#    6464,
#    6470,
#    6480,
#    6483,
#    6484,
#    6490,
#    6505,
#    6522,
#    6530,
#    6541,
#    6543,
#    6561,
#    6566,
#    6568,
#    6576,
#    6594,
#    6609,
#    6610,
#    6611,
#    6612,
#    6613,
#    6623,
#    6669,
#    6713,
#    6715,
#    6732,
#    6734,
#    6751,
#    6755,
#    6757,
#    6780,
#    6784,
#    6814,
#    6825,
#    6851,
#    6853,
#    6855,
#    6868,
#    6877,
#    6887,
#    6894,
#    6910,
#    6959,
#    6961,
#    6962,
#    6971,
#    6972,
#    6973,
#    6975,
#    6978,
#    6980,
#    6982,
#    6985,
#    6994,
#    6998,
#    7004,
#    7007,
#    7016,
#    7028,
#    7038]],
#  'ambient': [5, [5488, 5897, 6180, 6423, 7000]],
#  'ambulance': [1, [1939]],
#  'amchoor': [1, [6343]],
#  'ameen': [1, [5596]],
#  'amidst': [20,
#   [1263,
#    1444,
#    1445,
#    1859,
#    1956,
#    2482,
#    2546,
#    2725,
#    2981,
#    3283,
#    3544,
#    4362,
#    4439,
#    4530,
#    5191,
#    5269,
#    5673,
#    6010,
#    6257,
#    6618]],
#  'amma': [2, [2394, 6820]],
#  'amnesia': [1, [2610]],
#  'amoeba': [1, [3092]],
#  'among': [37,
#   [62,
#    234,
#    419,
#    469,
#    474,
#    512,
#    708,
#    802,
#    857,
#    1007,
#    1295,
#    1433,
#    1554,
#    1673,
#    1787,
#    1950,
#    2051,
#    2692,
#    3209,
#    3497,
#    3630,
#    3837,
#    4075,
#    4267,
#    4277,
#    4485,
#    4612,
#    4938,
#    5337,
#    5790,
#    5933,
#    6240,
#    6404,
#    6855,
#    6974,
#    6992,
#    6994]],
#  'amongst': [13,
#   [1215,
#    1230,
#    1264,
#    1575,
#    1744,
#    2537,
#    3309,
#    4416,
#    4498,
#    4791,
#    5002,
#    5330,
#    6604]],
#  'amount': [31,
#   [32,
#    60,
#    97,
#    244,
#    419,
#    667,
#    773,
#    823,
#    866,
#    929,
#    951,
#    1299,
#    1709,
#    1997,
#    2726,
#    2951,
#    3111,
#    3491,
#    4070,
#    4185,
#    4261,
#    4686,
#    4755,
#    4835,
#    5065,
#    5069,
#    6024,
#    6118,
#    6260,
#    6447,
#    6744]],
#  'amour': [1, [4632]],
#  'ample': [12,
#   [742, 1186, 1401, 1549, 2248, 2693, 2926, 3076, 3372, 5269, 5629, 5959]],
#  'amrita': [1, [6603]],
#  'amuse': [1, [621]],
#  'ana': [1, [1507]],
#  'ananda': [4, [211, 424, 588, 3357]],
#  'ancient': [2, [2658, 5283]],
#  'anda': [2, [101, 220]],
#  'angel': [3, [762, 5092, 6384]],
#  'angry': [2, [2288, 2839]],
#  'anime': [1, [2433]],
#  'anna': [2, [112, 1307]],
#  'anniversary': [7, [1513, 2552, 2601, 3193, 6227, 6962, 6984]],
#  'annoy': [1, [2348]],
#  'annual': [2, [3223, 5914]],
#  'another': [128,
#   [152,
#    234,
#    242,
#    283,
#    310,
#    326,
#    343,
#    353,
#    354,
#    464,
#    472,
#    474,
#    484,
#    610,
#    740,
#    750,
#    760,
#    767,
#    1093,
#    1207,
#    1218,
#    1229,
#    1270,
#    1315,
#    1328,
#    1335,
#    1430,
#    1435,
#    1437,
#    1443,
#    1466,
#    1498,
#    1499,
#    1608,
#    1609,
#    1657,
#    1702,
#    1765,
#    1814,
#    1827,
#    1962,
#    2007,
#    2039,
#    2048,
#    2060,
#    2118,
#    2186,
#    2368,
#    2374,
#    2400,
#    2444,
#    2469,
#    2503,
#    2508,
#    2522,
#    2636,
#    2651,
#    2666,
#    2690,
#    2692,
#    2709,
#    2790,
#    2797,
#    2842,
#    2914,
#    2950,
#    3317,
#    3320,
#    3342,
#    3350,
#    3442,
#    3461,
#    3494,
#    3497,
#    3505,
#    3567,
#    3727,
#    3761,
#    4064,
#    4087,
#    4121,
#    4145,
#    4160,
#    4437,
#    4612,
#    4633,
#    4787,
#    4802,
#    4803,
#    4806,
#    4839,
#    4863,
#    4942,
#    4959,
#    4960,
#    4998,
#    5004,
#    5156,
#    5158,
#    5242,
#    5245,
#    5361,
#    5390,
#    5448,
#    5451,
#    5469,
#    5507,
#    5610,
#    5669,
#    5729,
#    5755,
#    5819,
#    5917,
#    5924,
#    5947,
#    6057,
#    6072,
#    6155,
#    6248,
#    6289,
#    6417,
#    6531,
#    6555,
#    6711,
#    6764,
#    6799,
#    6887,
#    6976]],
#  'answer': [2, [937, 4956]],
#  'anticipation': [1, [2695]],
#  'antioxidant': [1, [5418]],
#  'antique': [1, [2061]],
#  'anybody': [3, [24, 586, 871]],
#  'anyone': [31,
#   [190,
#    347,
#    392,
#    436,
#    502,
#    544,
#    571,
#    595,
#    702,
#    1008,
#    1253,
#    1277,
#    1400,
#    2052,
#    2196,
#    2757,
#    3099,
#    3296,
#    3473,
#    3725,
#    4169,
#    4377,
#    4483,
#    4526,
#    4701,
#    5161,
#    5200,
#    5585,
#    5807,
#    6374,
#    7026]],
#  'anything': [43,
#   [2,
#    87,
#    105,
#    151,
#    339,
#    369,
#    549,
#    756,
#    1065,
#    1090,
#    1408,
#    1444,
#    1490,
#    1594,
#    1597,
#    1758,
#    1875,
#    2001,
#    2208,
#    2336,
#    2357,
#    2362,
#    2690,
#    3052,
#    3547,
#    4099,
#    4192,
#    4522,
#    4553,
#    4593,
#    4898,
#    5009,
#    5089,
#    5161,
#    5233,
#    5361,
#    5380,
#    5392,
#    5480,
#    5765,
#    6436,
#    6544,
#    6582]],
#  'anywhere': [3, [222, 4235, 5834]],
#  'apart': [13,
#   [611,
#    1443,
#    2513,
#    3160,
#    4092,
#    4145,
#    4633,
#    4770,
#    4812,
#    5236,
#    5545,
#    5813,
#    5881]],
#  'apartment': [5, [50, 1767, 1800, 3181, 7026]],
#  'apparently': [6, [22, 761, 2046, 2219, 2371, 2579]],
#  'appeal': [7, [62, 1268, 1314, 1349, 4534, 4806, 5370]],
#  'appearance': [6, [455, 1193, 2487, 2852, 4020, 6071]],
#  'appetite': [8, [818, 1589, 1640, 1659, 4203, 4877, 5758, 5824]],
#  'appetizer': [1, [1943]],
#  'apple': [10, [136, 305, 1704, 1937, 2235, 3432, 3553, 3686, 4687, 6348]],
#  'apply': [1, [5378]],
#  'appointment': [1, [2000]],
#  'appreciate': [5, [2995, 3905, 4377, 4486, 6435]],
#  'apprehensive': [1, [4788]],
#  'approach': [3, [1331, 4534, 4688]],
#  'appropriate': [1, [3870]],
#  'approve': [1, [5806]],
#  'approximately': [1, [4811]],
#  'apt': [10, [581, 951, 1266, 1366, 1495, 4510, 4838, 5379, 5506, 6752]],
#  'aptly': [1, [2516]],
#  'aqua': [1, [2678]],
#  'arabesque': [1, [5806]],
#  'arbor': [1, [2503]],
#  'arcade': [2, [3297, 6936]],
#  'ardent': [2, [1985, 5138]],
#  'area': [129,
#   [84,
#    99,
#    192,
#    235,
#    236,
#    273,
#    381,
#    409,
#    427,
#    497,
#    505,
#    615,
#    720,
#    737,
#    741,
#    776,
#    911,
#    956,
#    1012,
#    1123,
#    1177,
#    1206,
#    1241,
#    1437,
#    1455,
#    1490,
#    1582,
#    1608,
#    1714,
#    1734,
#    1805,
#    1839,
#    1883,
#    1905,
#    1922,
#    1924,
#    1956,
#    1957,
#    1976,
#    1992,
#    2067,
#    2217,
#    2247,
#    2255,
#    2355,
#    2424,
#    2482,
#    2483,
#    2521,
#    2545,
#    2561,
#    2628,
#    2756,
#    2758,
#    2940,
#    3048,
#    3146,
#    3175,
#    3212,
#    3261,
#    3329,
#    3374,
#    3391,
#    3442,
#    3507,
#    3735,
#    3840,
#    3858,
#    3915,
#    3961,
#    3964,
#    3968,
#    4045,
#    4077,
#    4137,
#    4322,
#    4342,
#    4355,
#    4416,
#    4426,
#    4451,
#    4462,
#    4480,
#    4529,
#    4605,
#    4610,
#    4648,
#    4806,
#    4811,
#    4813,
#    4826,
#    4839,
#    4847,
#    4910,
#    5057,
#    5184,
#    5215,
#    5251,
#    5259,
#    5361,
#    5399,
#    5531,
#    5533,
#    5689,
#    5695,
#    5733,
#    5770,
#    5877,
#    5923,
#    6069,
#    6157,
#    6184,
#    6309,
#    6357,
#    6589,
#    6730,
#    6777,
#    6826,
#    6844,
#    6851,
#    6852,
#    6853,
#    6925,
#    6935,
#    6959,
#    6962,
#    6973,
#    6994,
#    7000]],
#  'arena': [7, [576, 1079, 1514, 2842, 5150, 5200, 6329]],
#  'arent': [13,
#   [1453,
#    1658,
#    1955,
#    2107,
#    2199,
#    3285,
#    3576,
#    3854,
#    4092,
#    5360,
#    5392,
#    5556,
#    6149]],
#  'aristocratic': [1, [2321]],
#  'arjun': [1, [5348]],
#  'arm': [1, [6855]],
#  'army': [1, [6793]],
#  'aroma': [11,
#   [1366, 1950, 2199, 2748, 2950, 3883, 3953, 4088, 4367, 5342, 5466]],
#  'aromatic': [1, [1983]],
#  'around': [196,
#   [9,
#    46,
#    62,
#    242,
#    277,
#    280,
#    318,
#    347,
#    519,
#    606,
#    649,
#    773,
#    803,
#  'aspect': [2, [161, 6903]],
#  'assembly': [1, [5081]],
#  'assi': [1, [4935]],
#  'associate': [2, [2617, 6710]],
#  'association': [1, [1283]],
#  'assort': [3, [199, 997, 2318]],
#  'assorted': [3, [852, 6708, 6970]],
#  'assortment': [1, [6584]],
#  'assume': [3, [2239, 4696, 4781]],
#  'assumption': [1, [106]],
#  'assure': [3, [1534, 2867, 3536]],
#  'assured': [1, [2926]],
#  'astonishingly': [1, [4416]],
#  'aswell': [2, [303, 797]],
#  'ate': [32,
#   [208,
#    226,
#    454,
#    728,
#    893,
#    995,
#    1100,
#    1699,
#    1702,
#    1709,
#    1739,
#    2001,
#    2907,
#    2955,
#    2990,
#    3229,
#    3427,
#    3474,
#    3549,
#    3601,
#    3910,
#    4220,
#    4458,
#    5154,
#    5570,
#    5914,
#    5954,
#    6078,
#    6576,
#    6628,
#    6691,
#    6712]],
#  'atmosphere': [24,
#   [91,
#    374,
#    716,
#    828,
#    876,
#    1107,
#    1522,
#    1837,
#    2057,
#    2126,
#    2274,
#    3084,
#    3204,
#    3676,
#    4138,
#    4180,
#    4308,
#    4476,
#    4654,
#    5905,
#    6075,
#    6079,
#    6087,
#    6173]],
#  'atom': [1, [1133]],
#  'atomic': [1, [2587]],
#  'atop': [1, [6734]],
#  'atrium': [1, [2035]],
#  'atrocious': [1, [3527]],
#  'atta': [2, [1643, 4036]],
#  'attach': [5, [1283, 1356, 1592, 3180, 3203]],
#  'attached': [1, [6304]],
#  'attack': [2, [2820, 2962]],
#  'attempt': [3, [1419, 1702, 6524]],
#  'attend': [7, [2212, 2364, 2411, 2463, 3217, 5947, 6259]],
#  'attention': [5, [278, 2968, 4796, 4854, 5331]],
#  'attentive': [3, [2846, 2906, 3574]],
#  'attentiveness': [1, [495]],
#  'attic': [1, [3528]],
#  'attitude': [12,
#   [932, 2289, 2369, 2817, 3431, 3618, 4389, 4948, 5043, 6010, 6104, 6615]],
#  'attract': [1, [720]],
#  'attraction': [6, [2071, 3247, 5045, 5236, 5250, 5294]],
#  'attractive': [5, [313, 2499, 3670, 5041, 5757]],
#  'august': [1, [1479]],
#  'auntie': [2, [3170, 6967]],
#  'aura': [3, [3383, 4421, 6131]],
#  'authentic': [361,
#   [3,
#    89,
#    94,
#    103,
#    133,
#    181,
#    183,
#    185,
#    193,
#    283,
#    286,
#    313,
#    381,
#    409,
#    412,
#    423,
#    462,
#    463,
#    472,
#    479,
#    481,
#    498,
#    544,
#    552,
#    566,
#    569,
#    571,
#    586,
#    605,
#    623,
#    644,
#    660,
#    692,
#    694,
#    708,
#    709,
#    719,
#    741,
#    776,
#    788,
#    792,
#    806,
#    819,
#    829,
#    849,
#    860,
#    889,
#    924,
#    945,
#    949,
#    955,
#    975,
#    983,
#    998,
#    999,
#    1030,
#    1089,
#    1100,
#    1111,
#    1174,
#    1185,
#    1210,
#    1218,
#    1255,
#    1301,
#    1310,
#    1357,
#    1376,
#    1378,
#    1400,
#    1453,
#    1482,
#    1553,
#    1570,
#    1590,
#    1603,
#    1606,
#    1640,
#    5056,
#    5153,
#    5177,
#    5224,
#    5236,
#    5241,
#    5331,
#    5337,
#    5438,
#    5488,
#    5493,
#    5523,
#    5530,
#    5534,
#    5571,
#    5662,
#    5678,
#    5728,
#    5817,
#    5852,
#    5866,
#    5876,
#    5961,
#    5980,
#    6131,
#    6541,
#    6623,
#    6673,
#    6712,
#    6769,
#    6780,
#    6793,
#    6988,
#    6993,
#    7001,
#    7014]],
#  'crab': [10, [891, 1110, 1751, 1814, 2325, 4555, 4993, 5159, 6446, 6694]],
#  'crack': [1, [1877]],
#  'cradle': [1, [2836]],
#  'craft': [1, [5503]],
#  'cramp': [4, [273, 4943, 5698, 6141]],
#  'cramped': [1, [477]],
#  'cranberry': [1, [263]],
#  'crap': [2, [2837, 3910]],
#  'crash': [1, [436]],
#  'crave': [146,
#   [31,
#    43,
#    93,
#    124,
#    148,
#    241,
#    346,
#    347,
#    362,
#    372,
#    419,
#    450,
#    462,
#    500,
#    554,
#    566,
#    579,
#    605,
#    613,
#    618,
#    623,
#    632,
#    650,
#    665,
#    679,
#    730,
#    737,
#    759,
#    788,
#    837,
#    847,
#    871,
#    997,
#    1001,
#    1170,
#    1185,
#    1303,
#    1304,
#    1380,
#    1421,
#    1464,
#    1466,
#    1513,
#    1529,
#    1542,
#    1576,
#    1634,
#    1680,
#    1759,
#    1865,
#    1881,
#    1927,
#    2054,
#    2122,
#    2146,
#    2198,
#    2215,
#    2234,
#    2241,
#    2279,
#    2312,
#    2405,
#    2536,
#    2652,
#    2790,
#    2848,
#    2852,
#    2866,
#    2915,
#    2983,
#    3031,
#    3076,
#    3107,
#    3126,
#    3169,
#    3247,
#    3251,
#    3488,
#    3511,
#    3522,
#    3566,
#    3597,
#    3612,
#    3613,
#    3629,
#    3747,
#    3849,
#    3853,
#    3854,
#    3868,
#    3873,
#    3925,
#    4023,
#    4115,
#    4196,
#    4251,
#    4307,
#    4345,
#    4423,
#    4443,
#    4550,
#    4555,
#    4596,
#    4679,
#    4702,
#    4782,
#    4839,
#    4845,
#    4884,
#    4897,
#    4919,
#    4976,
#    4992,
#    5103,
#    5159,
#    5184,
#    5283,
#    5437,
#    5514,
#    5544,
#    5628,
#    5691,
#    5713,
#    5877,
#    5989,
#    5990,
#    6074,
#    6135,
#    6147,
#    6168,
#    6212,
#    6275,
#    6335,
#    6450,
#    6457,
#    6489,
#    6496,
#    6518,
#    6604,
#    6608,
#    6682,
#    6702,
#    6903,
#    6939,
#    6968,
#    7013]],
#  'craving': [19,
#   [579,
#    654,
#    721,
#    825,
#    1529,
#    1672,
#    2404,
#    2997,
#    3296,
#    3344,
#    3402,
#    3522,
#    3601,
#    3642,
#    3775,
#    4845,
#    4897,
#    5320,
#    5544]],
#  'crawl': [1, [3670]],
#  'craze': [2, [1192, 3963]],
#  'crazy': [35,
#   [182,
#    605,
#    806,
#    884,
#    1113,
#    1271,
#    1313,
#    1522,
#    1618,
#    2142,
#    2783,
#    2891,
#    3164,
#    3440,
#    3633,
#    3687,
#    3797,
#    3926,
#    4023,
#    4485,
#    4605,
#    4933,
#    5096,
#    5482,
#    5746,
#    5815,
#    5950,
#    6168,
#    6241,
#    6437,
#    6550,
#    6610,
#    6633,
#    6920,
#    6971]],
#  'creak': [1, [3962]],
#  'cream': [132,
#   [8,
#    16,
#    29,
#    50,
#    71,
#    81,
#    88,
#    93,
#    108,
#    122,
#    124,
#    152,
#    199,
#    222,
#    263,
#    300,
#    316,
#    365,
#    366,
#    420,
#    590,
#    639,
#    643,
#    770,
#    826,
#    888,
#    900,
#    921,
#    940,
#    947,
#    1041,
#    1071,
#    1086,
#    1114,
#    1167,
#    1186,
#    1191,
#    1197,
#    1309,
#    1332,
#    1350,
#    1351,
#    1352,
#    1435,
#    1436,
#    1532,
#    1627,
#    1642,
#    1676,
#    1704,
#    1712,
#    1718,
#    1761,
#    1770,
#    1831,
#    1855,
#    1860,
#    2061,
#    2076,
#    2095,
#    2156,
#    2199,
#    2230,
#    2269,
#    2293,
#    2315,
#    2410,
#    2679,
#    2680,
#    2783,
#    2820,
#    2992,
#    3000,
#    3030,
#    3057,
#    3110,
#    3184,
#    3195,
#    3288,
#    3393,
#    3401,
#    3458,
#    3553,
#    3583,
#    3599,
#    3610,
#    3639,
#    3822,
#    3920,
#    3926,
#    3962,
#    3966,
#    3975,
#    4253,
#    4266,
#    4281,
#    4410,
#    4604,
#    4636,
#    4794,
#    4799,
#    4931,
#    4965,
#    4998,
#    5035,
#    5123,
#    5141,
#    5263,
#    5273,
#    5282,
#    5450,
#    5492,
#    5604,
#    5632,
#    5670,
#    5763,
#    5802,
#    5803,
#    5896,
#    6024,
#    6087,
#    6198,
#    6200,
#    6205,
#    6208,
#    6219,
#    6346,
#    6427,
#    6575,
#    6698,
#    6728,
#    6730]],
#  'creamy': [11,
#   [53, 718, 2038, 2055, 2728, 2743, 3101, 3570, 4015, 4880, 6346]],
#  'create': [2, [1632, 5976]],
#  'creation': [1, [5069]],
#  'creative': [9, [1268, 1318, 2311, 3350, 3617, 4799, 5604, 6436, 6721]],
#  'creatively': [2, [4567, 4872]],
#  'creek': [1, [6971]],
#  'creepy': [1, [5081]],
#  'crepe': [4, [1003, 2090, 2218, 3954]],
#  'crescent': [2, [2364, 4611]],
#  'crest': [1, [5487]],
#  'crew': [1, [760]],
#  'cricket': [2, [4972, 5896]],
#  'crisp': [15,
#   [190,
#    448,
#    771,
#    1125,
#    1281,
#    1397,
#    1437,
#    2318,
#    2949,
#    2990,
#    4620,
#    4827,
#    4845,
#    4873,
#    6266]],
#  'crispy': [54,
#   [56,
#    67,
#    147,
#    159,
#    235,
#    283,
#    289,
#    316,
#    337,
#    395,
#    410,
#    438,
#    697,
#    740,
#    759,
#    793,
#    1170,
#    1221,
#    1337,
#    1443,
#    1470,
#    1535,
#    1560,
#    1617,
#    1647,
#    1690,
#    1711,
#    1893,
#    2201,
#    2258,
#    2383,
#    2435,
#    2885,
#    3109,
#    3180,
#    3284,
#    3570,
#    3853,
#    4085,
#    4113,
#    4245,
#    4370,
#    4503,
#    4844,
#    4865,
#    4914,
#    4968,
#    5129,
#    5132,
#    5989,
#    6149,
#    6303,
#    6413,
#    6464]],
#  'criticism': [1, [5664]],
#  'cross': [25,
#   [266,
#    292,
#    1265,
#    1456,
#    2410,
#    2456,
#    2744,
#    2910,
#    2960,
#    3436,
#    3880,
#    3890,
#    3990,
#    4456,
#    4550,
#    4647,
#    4660,
#    4792,
#    4863,
#    4880,
#    4888,
#    5352,
#    5869,
#    6041,
#    6152]],
#  'crossing': [1, [5117]],
#  'crow': [1, [585]],
#  'crowd': [118,
#   [64,
#    78,
#    95,
#    154,
#    196,
#    210,
#    221,
#    352,
#    399,
#    463,
#    528,
#    558,
#    565,
#    605,
#    907,
#    1109,
#    1199,
#    1253,
#    1324,
#    1335,
#    1436,
#    1443,
#    1448,
#    1452,
#    1460,
#    1649,
#    1703,
#    1708,
#    1729,
#    1749,
#    1806,
#    2127,
#    2255,
#    2270,
#    2381,
#    2390,
#    2424,
#    2508,
#    2527,
#    2544,
#    2571,
#    2593,
#    2624,
#    2687,
#    2705,
#    2707,
#    2718,
#    2849,
#    2915,
#    3040,
#    3196,
#    3249,
#    3271,
#    3280,
#    3296,
#    3541,
#    3554,
#    3557,
#    3582,
#    3678,
#    3776,
#    3879,
#    3880,
#    3982,
#    4010,
#    4018,
#    4026,
#    4061,
#    4115,
#    4174,
#    4520,
#    4529,
#    4616,
#    4869,
#    4882,
#    4986,
#    4995,
#    5009,
#    5075,
#    5131,
#    5149,
#    5152,
#    5176,
#    5182,
#    5219,
#    5232,
#    5238,
#    5269,
#    5335,
#    5361,
#    5413,
#    5597,
#    5613,
#    5662,
#    5664,
#    5737,
#    5848,
#    5889,
#    5902,
#    5990,
#    6044,
#    6052,
#    6101,
#    6141,
#    6219,
#    6224,
#    6276,
#    6303,
#    6335,
#    6431,
#    6452,
#    6474,
#    6590,
#    6607,
#    6670,
#    6861,
#    6962,
#    6975]],
#  'crowded': [10, [1762, 2349, 3087, 3363, 3557, 4174, 4208, 4887, 6198, 6671]],
#  'crowdy': [3, [3286, 3761, 3811]],
#  'crown': [3, [951, 5056, 5749]],
#  'crumb': [2, [794, 2215]],
#  'crumble': [1, [3686]],
#  'crumple': [1, [3263]],
#  'crunch': [8, [192, 321, 696, 1662, 2213, 3649, 4859, 5657]],
#  'crunchy': [15,
#   [1074,
#    1145,
#    1813,
#    2213,
#    2895,
#    3667,
#    3891,
#    4096,
#    5072,
#    5327,
#    5762,
#    5967,
#    6006,
#    6248,
#    6550]],
#  'crush': [1, [3164]],
#  'crust': [18,
#   [32,
#    191,
#    750,
#    951,
#    1534,
#    1775,
#    2046,
#    2075,
#    2394,
#    3705,
#    4890,
#    5129,
#    5475,
#    5876,
#    6081,
#    6472,
#    6684,
#    6891]],
#  'crusty': [1, [2318]],
#  'crystal': [1, [5858]],
#  'cube': [1, [2292]],
#  'cuboidal': [1, [963]],
#  'cucumber': [2, [708, 5666]],
#  'cud': [1, [4070]],
#  'cuddle': [1, [906]],
#  'cuisine': [140,
#   [55,
#    91,
#    133,
#    184,
#    205,
#    289,
#    343,
#    389,
#    632,
#    635,
#    660,
#    662,
#    694,
#    720,
#    806,
#    955,
#    1205,
#    1216,
#    1226,
#    1240,
#    1378,
#    1401,
#    1492,
#    1515,
#    1522,
#    1548,
#    1580,
#    1617,
#    1658,
#    1776,
#    1791,
#    1828,
#    1888,
#    1894,
#    1999,
#    2118,
#    2240,
#    2251,
#    2295,
#    2309,
#    2313,
#    2316,
#    2321,
#    2327,
#    2328,
#    2338,
#    2369,
#    2436,
#    2437,
#    2469,
#    2526,
#    2532,
#    2552,
#    2771,
#    2775,
#    2852,
#    2906,
#    2939,
#    2983,
#    2995,
#    3087,
#    3107,
#    3118,
#    3150,
#    3156,
#    3169,
#    3206,
#    3243,
#    3247,
#    3308,
#    3311,
#    3359,
#    3405,
#    3420,
#    3469,
#    3483,
#    3511,
#    3552,
#    3561,
#    3606,
#    3673,
#    3713,
#    3776,
#    3850,
#    4031,
#    4038,
#    4049,
#    4055,
#    4110,
#    4117,
#    4169,
#    4215,
#    4230,
#    4243,
#    4251,
#    4328,
#    4336,
#    4344,
#    4490,
#    4497,
#    4499,
#    4530,
#    4686,
#    4688,
#    4770,
#    4921,
#    4961,
#    5161,
#    5183,
#    5212,
#    5326,
#    5327,
#    5429,
#    5443,
#    5504,
#    5519,
#    5593,
#    5755,
#    5759,
#    5889,
#    6004,
#    6013,
#    6127,
#    6164,
#    6168,
#    6184,
#    6227,
#    6248,
#    6316,
#    6354,
#    6536,
#    6571,
#    6582,
#    6652,
#    6655,
#    6718,
#    6816,
#    6845,
#    6880,
#    7002]],
#  'culinary': [4, [4359, 5147, 5834, 6984]],
#  'cult': [2, [619, 662]],
#  'cultch': [1, [2717]],
#  'cultural': [1, [2352]],
#  'culture': [2, [5723, 6054]],
#  'cum': [11, [341, 526, 554, 1273, 1322, 1553, 2071, 2193, 3991, 4963, 6225]],
#  'cumin': [1, [1118]],
#  'cunning': [1, [138]],
#  'cup': [39,
#   [340,
#    906,
#    937,
#    940,
#    956,
#    1047,
#    1114,
#    1149,
#    1328,
#    1331,
#    1336,
#    1367,
#    1396,
#    1528,
#    1536,
#    1755,
#    1784,
#    2099,
#    2153,
#    2586,
#    3461,
#    3482,
#    3864,
#    4567,
#    4578,
#    4855,
#    4874,
#    5086,
#    5123,
#    5176,
#    5220,
#    5553,
#    5664,
#    5922,
#    6390,
#    6585,
#    6727,
#    6860,
#    6872]],
#  'cupcake': [7, [940, 1906, 3369, 5089, 5123, 6222, 6957]],
#  'curd': [18,
#   [353,
#    403,
#    887,
#    890,
#    1218,
#    1639,
#    1755,
#    3114,
#    3647,
#    4265,
#    4268,
#    4372,
#    4752,
#    5097,
#    5502,
#    5699,
#    5988,
#    6741]],
#  ...}

# %% [markdown]
# ## CREATING BIGRAM INVERTED INDEX

# %%
bigrams = {}
words = []
for i in range(dataframe.shape[0]):
    for word in dataframe.iloc[i,1].split():
        if word not in words:
            words.append(word)
            new = '$'+word+'$'
            for i in range(len(word)):
                if new[i:i+2] not in bigrams:
                    bigrams[new[i:i+2]] = [word]
                else:
                    bigrams[new[i:i+2]].append(word)

# %%
bigrams
# Out:
# {'$b': ['beautiful',
#   'best',
#   'bad',
#   'bite',
#   'big',
#   'buffet',
#   'bar',
#   'back',
#   'bit',
#   'busy',
#   'book',
#   'bunch',
#   'barbecue',
#   'break',
#   'base',
#   'bath',
#   'branch',
#   'board',
#   'become',
#   'bake',
#   'butter',
#   'box',
#   'bone',
#   'benne',
#   'basket',
#   'basically',
#   'bakery',
#   'beside',
#   'bread',
#   'belong',
#   'breakfast',
#   'beer',
#   'bear',
#   'baker',
#   'bowl',
#   'brilliant',
#   'behind',
#   'boy',
#   'bull',
#   'bottle',
#   'blend',
#   'budget',
#   'beat',
#   'brownie',
#   'blow',
#   'brain',
#   'blue',
#   'buy',
#   'block',
#   'broken',
#   'brightly',
#   'bugle',
#   'bot',
#   'brunch',
#   'bed',
#   'belief',
#   'birthday',
#   'bought',
#   'bring',
#   'black',
#   'blessing',
#   'buzz',
#   'belt',
#   'boil',
#   'begin',
#   'bold',
#   'behavior',
#   'button',
#   'brand',
#   'bun',
#   'believe',
#   'bright',
#   'blast',
#   'boneless',
#   'baby',
#   'blueberry',
#   'bum',
#   'brigade',
#   'butterscotch',
#   'brown',
#   'brew',
#   'brewery',
#   'bel',
#   'birth',
#   'baa',
#   'better',
#   'bustle',
#   'bullet',
#   'bus',
#   'banana',
#   'belly',
#   'bedridden',
#   'basis',
#   'b',
#   'baked',
#   'bungalow',
#   'bland',
#   'business',
#   'blissful',
#   'balance',
#   'beverage',
#   'booking',
#   'bank',
#   'basic',
#   'bet',
#   'bahut',
#   'bag',
#   'burrito',
#   'bucket',
#   'beware',
#   'babu',
#   'bong',
#   'behaviour',
#   'burnt',
#   'body',
#   'builder',
#   'bacon',
#   'bib',
#   'basil',
#   'badly',
#   'bearer',
#   'berry',
#   'bean',
#   'breezy',
#   'bill',
#   'build',
#   'blink',
#   'baba',
#   'burg',
#   'bawarchi',
#   'beautifully',
#   'bomb',
#   'bitter',
#   'bamboo',
#   'bubble',
#   'beef',
#   'bare',
#   'booze',
#   'buddy',
#   'bridge',
#   'boa',
#   'burp',
#   'bless',
#   'brittle',
#   'breacher',
#   'binge',
#   'bay',
#   'burn',
#   'broad',
#   'bazaar',
#   'batter',
#   'bistro',
#   'bliss',
#   'beauty',
#   'brother',
#   'buttercup',
#   'born',
#   'bari',
#   'booked',
#   'blanc',
#   'brewing',
#   'behalf',
#   'bahar',
#   'bang',
#   'barely',
#   'broadway',
#   'brassiere',
#   'bulb',
#   'broccoli',
#   'bhara',
#   'bogo',
#   'bewilder',
#   'basement',
#   'blowing',
#   'bottom',
#   'building',
#   'brimstone',
#   'blissfully',
#   'blot',
#   'boom',
#   'batata',
#   'beetroot',
#   'bike',
#   'balcony',
#   'bara',
#   'bin',
#   'bon',
#   'bakehouse',
#   'brick',
#   'blackboard',
#   'bowel',
#   'bae',
#   'bicycle',
#   'brandy',
#   'briefly',
#   'bundle',
#   'bother',
#   'bootlegger',
#   'breath',
#   'bud',
#   'bustling',
#   'blindly',
#   'bulk',
#   'barn',
#   'burning',
#   'bout',
#   'barton',
#   'boon',
#   'bore',
#   'billing',
#   'bi',
#   'beau',
#   'boulevard',
#   'ball',
#   'besan',
#   'boondock',
#   'blonde',
#   'bole',
#   'besides',
#   'beet',
#   'breeze',
#   'boast',
#   'bismillah',
#   'beyond',
#   'buck',
#   'buff',
#   'boho',
#   'benefit',
#   'billionaire',
#   'boston',
#   'blore',
#   'bearfoot',
#   'buzzy',
#   'buttery',
#   'boozy',
#   'bowls',
#   'band',
#   'baar',
#   'bali',
#   'beach',
#   'behave',
#   'butterfly',
#   'brought',
#   'bracket',
#   'bunny',
#   'background',
#   'bond',
#   'bookmark',
#   'boat',
#   'bachelor',
#   'beginning',
#   'burner',
#   'becomes',
#   'browse',
#   'bait',
#   'bade',
#   'baking',
#   'bing',
#   'bizarre',
#   'bloody',
#   'breast',
#   'batman',
#   'buggy',
#   'beacon',
#   'bos',
#   'banga',
#   'bat',
#   'batch',
#   'beguiling',
#   'bloom',
#   'blister',
#   'brewhouse',
#   'buttermilk',
#   'buster',
#   'bump',
#   'bast',
#   'bier',
#   'brief',
#   'bene',
#   'blame',
#   'bas',
#   'bingo',
#   'boss',
#   'bug',
#   'bonbon',
#   'bunker',
#   'biting',
#   'bell',
#   'barley'],
#  'be': ['beautiful',
#   'best',
#   'barbecue',
#   'become',
#   'benne',
#   'beside',
#   'belong',
#   'beer',
#   'bear',
#   'behind',
#   'beat',
#   'number',
#   'bed',
#   'belief',
#   'belt',
#   'begin',
#   'iceberg',
#   'behavior',
#   'cranberry',
#   'believe',
#   'strawberry',
#   'blueberry',
#   'describe',
#   'bel',
#   'remember',
#   'better',
#   'belly',
#   'bedridden',
#   'member',
#   'prescribe',
#   'beverage',
#   'bet',
#   'beware',
#   'behaviour',
#   'cucumber',
#   'unbelievably',
#   'bearer',
#   'berry',
#   'bean',
#   'beautifully',
#   'sober',
#   'beef',
#   'unbelievable',
#   'maybe',
#   'beauty',
#   'rubber',
#   'imbibe',
#   'upbeat',
#   'behalf',
#   'raspberry',
#   'bewilder',
#   'tribe',
#   'beetroot',
#   'cube',
#   'amber',
#   'tibet',
#   'unbeatable',
#   'beau',
#   'besan',
#   'besides',
#   'beet',
#   'albeit',
#   'beyond',
#   'globe',
#   'benefit',
#   'bearfoot',
#   'membership',
#   'beach',
#   'behave',
#   'beginning',
#   'becomes',
#   'beacon',
#   'beguiling',
#   'arabesque',
#   'disturbed',
#   'timber',
#   'bene',
#   'rubbery',
#   'ember',
#   'bell'],
#  'ea': ['beautiful',
#   'near',
#   'team',
#   'really',
#   'great',
#   'heavy',
#   'spread',
#   'cream',
#   'easy',
#   'year',
#   'eatery',
#   'read',
#   'easily',
#   'nearby',
#   'break',
#   'tea',
#   'pleasant',
#   'please',
#   'sea',
#   'yeah',
#   'reason',
#   'dear',
#   'freak',
#   'treat',
#   'meal',
#   'eaten',
#   'colleague',
#   'eat',
#   'least',
#   'neatly',
#   'healthy',
#   'feast',
#   'creamy',
#   'meant',
#   'cheap',
#   'appeal',
#   'repeatedly',
#   'wheat',
#   'bread',
#   'head',
#   'breakfast',
#   'ideal',
#   'mislead',
#   'reach',
#   'bear',
#   'seat',
#   'search',
#   'reading',
#   'reasonable',
#   'area',
#   'early',
#   'meat',
#   'death',
#   'beat',
#   'reasonably',
#   'health',
#   'heart',
#   'cheat',
#   'mean',
#   'clean',
#   'clear',
#   'east',
#   'leave',
#   'neat',
#   'cleaner',
#   'research',
#   'treating',
#   'ready',
#   'steam',
#   'seating',
#   'real',
#   'instead',
#   'heaven',
#   'weather',
#   'already',
#   'eagerly',
#   'hear',
#   'hearted',
#   'eating',
#   'appearance',
#   'peaceful',
#   'pleasantly',
#   'leaf',
#   'peace',
#   'idea',
#   'eager',
#   'eastern',
#   'eats',
#   'cleanly',
#   'repeat',
#   'mealer',
#   'eatable',
#   'speak',
#   'uneatable',
#   'cheating',
#   'unclean',
#   'headache',
#   'dream',
#   'heathy',
#   'heartbreaking',
#   'heartbreaking',
#   'heavily',
#   'bearer',
#   'bean',
#   'heavenly',
#   'pleasure',
#   'beautifully',
#   'nuclear',
#   'pleasurable',
#   'cleanliness',
#   'eagle',
#   'steak',
#   'earth',
#   'breacher',
#   'peach',
#   'ahead',
#   'heat',
#   'hearing',
#   'creative',
#   'heartily',
#   'veal',
#   'beauty',
#   'cheater',
#   'manageable',
#   'readily',
#   'pearl',
#   'treatment',
#   'deal',
#   'upbeat',
#   'clearly',
#   'increase',
#   'learnt',
#   'create',
#   'mediterranean',
#   'peak',
#   'season',
#   'meaning',
#   'pineapple',
#   'earthy',
#   'unhealthy',
#   'earn',
#   'freaky',
#   'leakage',
#   'retreat',
#   'underneath',
#   'hearty',
#   'eater',
#   'treasure',
#   'peacefully',
#   'searching',
#   'breath',
#   'unbeatable',
#   'nearly',
#   'beau',
#   'scream',
#   'peanut',
#   'lead',
#   'dead',
#   'yea',
#   'pleasing',
#   'bearfoot',
#   'hereafter',
#   'meagre',
#   'greasy',
#   'easiness',
#   'beach',
#   'leading',
#   'ideally',
#   'cleaning',
#   'swear',
#   'creak',
#   'streak',
#   'teammate',
#   'displease',
#   'lean',
#   'realize',
#   'whereas',
#   'reassurance',
#   'creatively',
#   'reaction',
#   'teal',
#   'breast',
#   'weariness',
#   'neatness',
#   'feather',
#   'beacon',
#   'teapot',
#   'measly',
#   'creation',
#   'teashop',
#   'peat',
#   'teapoy',
#   'dreamland',
#   'feature',
#   'ear',
#   'misleading',
#   'oatmeal',
#   'deadly',
#   'flea',
#   'sweetmeat',
#   'stream',
#   'unreal',
#   'earthen',
#   'teach',
#   'uneasy',
#   'threat',
#   'nearest',
#   'dreamy',
#   'weakness',
#   'decrease',
#   'steal',
#   'increasingly',
#   'tease'],
#  'au': ['beautiful',
#   'restaurant',
#   'authentic',
#   'saucy',
#   'authenticity',
#   'fraudulent',
#   'sauce',
#   'daughter',
#   'default',
#   'sausage',
#   'gaud',
#   'beautifully',
#   'fraud',
#   'cause',
#   'inauguration',
#   'beauty',
#   'august',
#   'fault',
#   'naughty',
#   'laughing',
#   'caught',
#   'launch',
#   'draught',
#   'beau',
#   'auntie',
#   'aura',
#   'inaugural',
#   'cautious',
#   'laughable',
#   'exhaust',
#   'haunt',
#   'causal',
#   'centaury',
#   'relaunch',
#   'jaunt',
#   'taught',
#   'nautical'],
#  'ut': ['beautiful',
#   'authentic',
#   'outdoor',
#   'cute',
#   'hangout',
#   'outlet',
#   'south',
#   'truth',
#   'butter',
#   'absolutely',
#   'southwestern',
#   'authenticity',
#   'out',
#   'mouth',
#   'cut',
#   'chutney',
#   'without',
#   'mutton',
#   'hut',
#   'minute',
#   'utter',
#   'coconut',
#   'layout',
#   'absolute',
#   'button',
#   'cutlet',
#   'outside',
#   'put',
#   'butterscotch',
#   'nutritious',
#   'outstanding',
#   'executive',
#   'walnut',
#   'bahut',
#   'mouthful',
#   'doughnut',
#   'shut',
#   'commute',
#   'utmost',
#   'cuteness',
#   'clutter',
#   'hazelnut',
#   'beautifully',
#   'dutch',
#   'utterly',
#   'suttle',
#   'uta',
#   'outstation',
#   'outdated',
#   'beauty',
#   'buttercup',
#   'mutter',
#   'outer',
#   'tryout',
#   'sprout',
#   'nutty',
#   'execute',
#   'southwest',
#   'lookout',
#   'gluten',
#   'southern',
#   'institution',
#   'outdoors',
#   'outfit',
#   'bout',
#   'shout',
#   'peanut',
#   'throughout',
#   'putt',
#   'distribute',
#   'buttery',
#   'reputed',
#   'solution',
#   'nutrition',
#   'chestnut',
#   'putty',
#   'nut',
#   'butterfly',
#   'pout',
#   'sutra',
#   'cautious',
#   'scout',
#   'cutlery',
#   'outset',
#   'institute',
#   'outstandingly',
#   'future',
#   'buttermilk',
#   'mutiny',
#   'handout',
#   'acute',
#   'mutual',
#   'route',
#   'output',
#   'output',
#   'workout',
#   'salute',
#   'reputation',
#   'nautical',
#   'repute',
#   'uppercut'],
#  'ti': ['beautiful',
#   'time',
#   'authentic',
#   'international',
#   'location',
#   'multiple',
#   'presentation',
#   'tiny',
#   'exotic',
#   'ventilation',
#   'ventilation',
#   'quantity',
#   'condition',
#   'pathetic',
#   'option',
#   'rating',
#   'timer',
#   'timely',
#   'satiable',
#   'till',
#   'continental',
#   'authenticity',
#   'satisfy',
#   'preparation',
#   'satisfaction',
#   'satisfaction',
#   'unsatisfied',
#   'portion',
#   'junction',
#   'scrumptious',
#   'pathetically',
#   'still',
#   'traditional',
#   'assumption',
#   'conversation',
#   'sometime',
#   'section',
#   'negative',
#   'sometimes',
#   'patio',
#   'mention',
#   'aesthetic',
#   'ultimate',
#   'addition',
#   'multitude',
#   'introduction',
#   'essentially',
#   'tire',
#   'national',
#   'particularly',
#   'celebration',
#   'majestic',
#   'destination',
#   'destination',
#   'artistic',
#   'artistic',
#   'combination',
#   'entire',
#   'unidentified',
#   'tikka',
#   'treating',
#   'satiate',
#   'continuous',
#   'rustic',
#   'identifiable',
#   'emotion',
#   'attention',
#   'interesting',
#   'satisfied',
#   'seating',
#   'attractive',
#   'collaboration',
#   'fantastic',
#   'station',
#   'situation',
#   'relatively',
#   'initially',
#   'renovation',
#   'tiffin',
#   'nutritious',
#   'satisfying',
#   'tidy',
#   'particular',
#   'potential',
#   'expectation',
#   'residential',
#   'competition',
#   'competition',
#   'eating',
#   'inception',
#   'nation',
#   'attentiveness',
#   'collection',
#   'untidy',
#   'description',
#   'prestige',
#   'times',
#   'executive',
#   'stick',
#   'stink',
#   'innovative',
#   'cheating',
#   'comparatively',
#   'innovation',
#   'spaghetti',
#   'tasting',
#   'tight',
#   'positive',
#   'festive',
#   'decorative',
#   'appetite',
#   'distinct',
#   'notice',
#   'meeting',
#   'beautifully',
#   'selective',
#   'attitude',
#   'optimal',
#   'generation',
#   'tired',
#   'addiction',
#   'waiting',
#   'recommendation',
#   'justify',
#   'potion',
#   'disgusting',
#   'skeptical',
#   'simplistic',
#   'plastic',
#   'functional',
#   'timing',
#   'effective',
#   'notification',
#   'notification',
#   'exceptional',
#   'representation',
#   'tice',
#   'multiplex',
#   'romantic',
#   'lifetime',
#   'selection',
#   'creative',
#   'outstation',
#   'heartily',
#   'association',
#   'tortilla',
#   'inauguration',
#   'exceptionally',
#   'quintessential',
#   'unquestionably',
#   'visiting',
#   'exaggeration',
#   'tipsy',
#   'greeting',
#   'untill',
#   'tit',
#   'recognition',
#   'coronation',
#   'matinee',
#   'melting',
#   'conditionally',
#   'limitation',
#   'instruction',
#   'sticky',
#   'competitor',
#   'festival',
#   'artistically',
#   'artistically',
#   'relation',
#   'tick',
#   'hectic',
#   'artificial',
#   'appetizer',
#   'meticulously',
#   'aromatic',
#   'lighting',
#   'tiger',
#   'sophisticated',
#   'intersection',
#   'antique',
#   'sensation',
#   'attraction',
#   'disappointing',
#   'interpretation',
#   'hoti',
#   'justice',
#   'writing',
#   'petite',
#   'satin',
#   'excruciatingly',
#   'tip',
#   'patience',
#   'sitting',
#   'erratic',
#   'infection',
#   'aristocratic',
#   'institution',
#   'institution',
#   'competitive',
#   'competitive',
#   'decoration',
#   'corporation',
#   'stir',
#   'rendition',
#   'variation',
#   'suggestion',
#   'tingler',
#   'drastically',
#   'patisserie',
#   'entirely',
#   'tibet',
#   'eclectic',
#   'relative',
#   'energetic',
#   'tile',
#   'setting',
#   'quintessentially',
#   'sentiment',
#   'anticipation',
#   'anticipation',
#   'initiative',
#   'initiative',
#   'tissue',
#   'attentive',
#   'ultimately',
#   'hostile',
#   'denomination',
#   'question',
#   'unsatisfying',
#   'tie',
#   'satisfactory',
#   'auntie',
#   'confectioner',
#   'entice',
#   'portico',
#   'tickle',
#   'drumstick',
#   'unnoticed',
#   'function',
#   'sticker',
#   'reception',
#   'unostentatious',
#   'reservation',
#   'explanation',
#   'unpretentious',
#   'sentimental',
#   'tastiness',
#   'definition',
#   'problematic',
#   'attic',
#   'solution',
#   'nutrition',
#   'intimate',
#   'vacation',
#   'population',
#   'invitation',
#   'interaction',
#   'information',
#   'stint',
#   'tilt',
#   'tiffany',
#   'operational',
#   'comforting',
#   'cautious',
#   'promotional',
#   'shifting',
#   'exciting',
#   'dissatisfy',
#   'position',
#   'emotional',
#   'creatively',
#   'title',
#   'consideration',
#   'reaction',
#   'fanatic',
#   'clandestine',
#   'subscription',
#   'perfection',
#   'initial',
#   'institute',
#   'unattentive',
#   'comparative',
#   'tradition',
#   'foundation',
#   'alternative',
#   'creation',
#   'tippler',
#   'negotiate',
#   'intention',
#   'exoticism',
#   'multifold',
#   'essential',
#   'native',
#   'mutiny',
#   'antioxidant',
#   'scintillate',
#   'criticism',
#   'transaction',
#   'everlasting',
#   'conventional',
#   'distinguished',
#   'communication',
#   'motive',
#   'exploration',
#   'fascination',
#   'titanic',
#   'timber',
#   'exhibition',
#   'prakriti',
#   'aesthetically',
#   'versatile',
#   'sweetie',
#   'shakti',
#   'partial',
#   'latitude',
#   'vegetation',
#   'justification',
#   'justification',
#   'active',
#   'pristine',
#   'relationship',
#   'chopstick',
#   'organization',
#   'fascinatingly',
#   'idiotic',
#   'pretentiously',
#   'qualitative',
#   'sophisticate',
#   'quantify',
#   'reputation',
#   'distinction',
#   'distinction',
#   'biting',
#   'nautical',
#   'stingy',
#   'valentine',
#   'notion'],
#  'if': ['beautiful',
#   'life',
#   'wife',
#   'different',
#   'specifically',
#   'difference',
#   'difficult',
#   'unidentified',
#   'identifiable',
#   'tiffin',
#   'manifest',
#   'swift',
#   'alif',
#   'beautifully',
#   'justify',
#   'gift',
#   'makeshift',
#   'notification',
#   'lifetime',
#   'magnificent',
#   'chiffon',
#   'differently',
#   'artificial',
#   'fifth',
#   'terrific',
#   'shift',
#   'qualify',
#   'griffin',
#   'tiffany',
#   'specific',
#   'shifting',
#   'lifeline',
#   'whiff',
#   'uniform',
#   'multifold',
#   'significant',
#   'justification',
#   'quantify'],
#  'fu': ['beautiful',
#   'full',
#   'funky',
#   'fu',
#   'delightful',
#   'awful',
#   'fusion',
#   'fudge',
#   'careful',
#   'fun',
#   'wonderful',
#   'thoughtful',
#   'confusion',
#   'cheerful',
#   'fud',
#   'helpful',
#   'handful',
#   'fuss',
#   'peaceful',
#   'awfully',
#   'blissful',
#   'deceitful',
#   'mouthful',
#   'refund',
#   'colorful',
#   'beautifully',
#   'sinful',
#   'tofu',
#   'functional',
#   'fulfill',
#   'tasteful',
#   'fully',
#   'flavorful',
#   'potful',
#   'blissfully',
#   'thankful',
#   'purposefully',
#   'confuse',
#   'peacefully',
#   'defunct',
#   'delightfully',
#   'powerful',
#   'successfully',
#   'fuel',
#   'fund',
#   'thankfully',
#   'infusion',
#   'confused',
#   'funny',
#   'function',
#   'wonderfully',
#   'successful',
#   'soulful',
#   'forgetful',
#   'fudgy',
#   'spoonful',
#   'tastefully',
#   'future',
#   'hopefully',
#   'mugful',
#   'fungi',
#   'furniture'],
#  'ul': ['beautiful',
#   'full',
#   'multiple',
#   'regular',
#   'wouldnt',
#   'would',
#   'regularly',
#   'fraudulent',
#   'delightful',
#   'could',
#   'awful',
#   'bull',
#   'popular',
#   'careful',
#   'difficult',
#   'ultimate',
#   'multitude',
#   'wonderful',
#   'particularly',
#   'spectacular',
#   'thoughtful',
#   'dull',
#   'cheerful',
#   'helpful',
#   'handful',
#   'particular',
#   'fabulous',
#   'bullet',
#   'peaceful',
#   'indulge',
#   'truly',
#   'awfully',
#   'result',
#   'blissful',
#   'soul',
#   'cult',
#   'shouldnt',
#   'deceitful',
#   'mouthful',
#   'default',
#   'pulpy',
#   'colorful',
#   'succulent',
#   'beautifully',
#   'sinful',
#   'tulip',
#   'multiplex',
#   'fulfill',
#   'tasteful',
#   'pull',
#   'fully',
#   'popularity',
#   'flavorful',
#   'potful',
#   'spectacularly',
#   'bulb',
#   'ultra',
#   'fault',
#   'blissfully',
#   'thankful',
#   'purposefully',
#   'ambulance',
#   'meticulously',
#   'peacefully',
#   'ridiculous',
#   'cultural',
#   'delightfully',
#   'bulk',
#   'powerful',
#   'successfully',
#   'sultan',
#   'indulgence',
#   'thankfully',
#   'cultch',
#   'boulevard',
#   'ultimately',
#   'ridiculously',
#   'pulp',
#   'gulp',
#   'wonderfully',
#   'peculiar',
#   'population',
#   'successful',
#   'soulful',
#   'soulful',
#   'forgetful',
#   'popularly',
#   'culinary',
#   'spoonful',
#   'tastefully',
#   'impulse',
#   'multifold',
#   'hangul',
#   'hopefully',
#   'mugful',
#   'ull',
#   'culture',
#   'tulsi',
#   'pulka'],
#  '$p': ['place',
#   'platter',
#   'partner',
#   'price',
#   'people',
#   'proper',
#   'personally',
#   'pizza',
#   'penthouse',
#   'past',
#   'presentation',
#   'point',
#   'pay',
#   'pretty',
#   'pleasant',
#   'please',
#   'provide',
#   'probably',
#   'park',
#   'pathetic',
#   'pack',
#   'perfect',
#   'puff',
#   'person',
#   'prefer',
#   'pending',
#   'pepper',
#   'peppy',
#   'preparation',
#   'pastry',
#   'pocket',
#   'plate',
#   'previous',
#   'properly',
#   'problem',
#   'portion',
#   'pathetically',
#   'polar',
#   'pure',
#   'popular',
#   'pass',
#   'passing',
#   'poor',
#   'piece',
#   'platform',
#   'per',
#   'patio',
#   'parking',
#   'prompt',
#   'pine',
#   'pizzeria',
#   'present',
#   'parcel',
#   'paradise',
#   'prime',
#   'pip',
#   'petrol',
#   'peri',
#   'particularly',
#   'prior',
#   'professionalism',
#   'potato',
#   'package',
#   'prepare',
#   'plan',
#   'picture',
#   'page',
#   'par',
#   'party',
#   'plane',
#   'pomegranate',
#   'perfectly',
#   'plain',
#   'promise',
#   'president',
#   'prawn',
#   'preference',
#   'primarily',
#   'polite',
#   'pe',
#   'proprietor',
#   'powder',
#   'pork',
#   'pick',
#   'pickle',
#   'put',
#   'peda',
#   'prepared',
#   'pili',
#   'popcorn',
#   'poha',
#   'phoenix',
#   'phone',
#   'panner',
#   'particular',
#   'part',
#   'potential',
#   'pub',
#   'palace',
#   'possible',
#   'peaceful',
#   'pride',
#   'pleasantly',
#   'pickup',
#   'plenty',
#   'post',
#   'prescribe',
#   'pet',
#   'passion',
#   'profession',
#   'peace',
#   'p',
#   'phase',
#   'praiseworthy',
#   'plus',
#   'personal',
#   'prestige',
#   'plum',
#   'photo',
#   'priority',
#   'ponder',
#   'phew',
#   'picky',
#   'purely',
#   'packet',
#   'paper',
#   'private',
#   'pan',
#   'pancake',
#   'patty',
#   'pulpy',
#   'pile',
#   'parlor',
#   'pace',
#   'pungent',
#   'positive',
#   'potter',
#   'pleasure',
#   'pot',
#   'panther',
#   'puma',
#   'pump',
#   'professional',
#   'pleasurable',
#   'policy',
#   'property',
#   'permanently',
#   'potion',
#   'pas',
#   'power',
#   'panda',
#   'papa',
#   'plastic',
#   'palette',
#   'pie',
#   'product',
#   'produce',
#   'petal',
#   'peach',
#   'play',
#   'proudly',
#   'punch',
#   'passport',
#   'protein',
#   'pin',
#   'pomfret',
#   'poop',
#   'pull',
#   'praise',
#   'pop',
#   'previously',
#   'premiere',
#   'popularity',
#   'pirate',
#   'pearl',
#   'preferred',
#   'potful',
#   'pic',
#   'praline',
#   'pedicure',
#   'peak',
#   'poorly',
#   'pretense',
#   'pistachio',
#   'pineapple',
#   'purpose',
#   'pho',
#   'pool',
#   'pound',
#   'pita',
#   'pit',
#   'poison',
#   'purchase',
#   'pudding',
#   'petty',
#   'purposefully',
#   'prep',
#   'pokey',
#   'poolside',
#   'performance',
#   'proximity',
#   'paisa',
#   'palm',
#   'penny',
#   'pavilion',
#   'parade',
#   'pice',
#   'press',
#   'patron',
#   'pind',
#   'petite',
#   'proverb',
#   'peacefully',
#   'patience',
#   'puja',
#   'playground',
#   'penta',
#   'papaya',
#   'parish',
#   'palate',
#   'profile',
#   'prove',
#   'period',
#   'payment',
#   'preferable',
#   'privilege',
#   'patisserie',
#   'permit',
#   'pitcher',
#   'powerful',
#   'pun',
#   'plaza',
#   'pronounce',
#   'polo',
#   'player',
#   'prefect',
#   'posh',
#   'podium',
#   'paprica',
#   'primavera',
#   'perry',
#   'peek',
#   'possibly',
#   'peanut',
#   'process',
#   'palar',
#   'poster',
#   'pataka',
#   'precious',
#   'pro',
#   'premium',
#   'putt',
#   'pain',
#   'premier',
#   'pious',
#   'prop',
#   'portico',
#   'pannier',
#   'public',
#   'pleasing',
#   'phrase',
#   'puffed',
#   'pulp',
#   'problematic',
#   'promote',
#   'paramount',
#   'picket',
#   'potency',
#   'peculiar',
#   'population',
#   'putty',
#   'prominent',
#   'pepperoni',
#   'plague',
#   'parasol',
#   'pour',
#   'pal',
#   'predominantly',
#   'precise',
#   'pout',
#   'pair',
#   'perhaps',
#   'paint',
#   'popularly',
#   'payday',
#   'percent',
#   'peg',
#   'peril',
#   'promptly',
#   'prize',
#   'pillar',
#   'promotional',
#   'paddy',
#   'persist',
#   'phenomenal',
#   'pink',
#   'purple',
#   'position',
#   'purse',
#   'pina',
#   'promising',
#   'piano',
#   'panel',
#   'pad',
#   'pepperwood',
#   'perfection',
#   'pavan',
#   'pardon',
#   'preopening',
#   'planet',
#   'plantain',
#   'program',
#   'picturesque',
#   'preferably',
#   'portal',
#   'picked',
#   'pressure',
#   'preview',
#   'predictably',
#   'peat',
#   'passable',
#   'pipe',
#   'paste',
#   'pattern',
#   'paradox',
#   'pint',
#   'pig',
#   'playa',
#   'push',
#   'primal',
#   'passionate',
#   'path',
#   'pottery',
#   'plant',
#   'prakriti',
#   'poetry',
#   'pander',
#   'prana',
#   'partial',
#   'pamper',
#   'pristine',
#   'pulka',
#   'plush',
#   'pretentiously',
#   'passionately'],
#  'pl': ['place',
#   'platter',
#   'people',
#   'simple',
#   'multiple',
#   'couple',
#   'pleasant',
#   'please',
#   'complex',
#   'plate',
#   'someplace',
#   'completely',
#   'simplicity',
#   'platform',
#   'apple',
#   'simply',
#   'plan',
#   'plane',
#   'complete',
#   'plain',
#   'employee',
#   'unplanned',
#   'replica',
#   'explore',
#   'staple',
#   'temple',
#   'pleasantly',
#   'plenty',
#   'plus',
#   'plum',
#   'display',
#   'triple',
#   'ample',
#   'pleasure',
#   'replacement',
#   'displayed',
#   'splendid',
#   'incomplete',
#   'pleasurable',
#   'simplistic',
#   'split',
#   'plastic',
#   'example',
#   'multiplex',
#   'play',
#   'compliment',
#   'explain',
#   'explosion',
#   'unplug',
#   'workplace',
#   'pineapple',
#   'complaint',
#   'complimentary',
#   'complain',
#   'playground',
#   'deeply',
#   'replete',
#   'plaza',
#   'player',
#   'dumpling',
#   'duplicate',
#   'crumple',
#   'pleasing',
#   'explanation',
#   'plague',
#   'unexplainable',
#   'displease',
#   'purple',
#   'sample',
#   'planet',
#   'plantain',
#   'deplorable',
#   'employ',
#   'tippler',
#   'complement',
#   'esplanade',
#   'apply',
#   'playa',
#   'sampler',
#   'exploration',
#   'plant',
#   'supply',
#   'exemplary',
#   'plush'],
#  'la': ['place',
#   'platter',
#   'late',
#   'chocolate',
#   'flavor',
#   'land',
#   'regular',
#   'last',
#   'ventilation',
#   'available',
#   'salad',
#   'lack',
#   'regularly',
#   'class',
#   'plate',
#   'someplace',
#   'vanilla',
#   'large',
#   'similar',
#   'polar',
#   'popular',
#   'flavour',
#   'platform',
#   'particularly',
#   'plan',
#   'black',
#   'clam',
#   'plane',
#   'lady',
#   'plain',
#   'layout',
#   'spectacular',
#   'unplanned',
#   'blast',
#   'collaboration',
#   'classic',
#   'relatively',
#   'delay',
#   'flask',
#   'relaxed',
#   'lazy',
#   'particular',
#   'relate',
#   'palace',
#   'isolate',
#   'slate',
#   'relax',
#   'glad',
#   'bland',
#   'balance',
#   'display',
#   'glaze',
#   'labra',
#   'glance',
#   'replacement',
#   'village',
#   'displayed',
#   'lately',
#   'lamb',
#   'flaky',
#   'classy',
#   'glass',
#   'flavorsome',
#   'chola',
#   'plastic',
#   'lake',
#   'flag',
#   'gola',
#   'lava',
#   'landed',
#   'play',
#   'villa',
#   'la',
#   'collage',
#   'lane',
#   'tortilla',
#   'explain',
#   'landmark',
#   'lay',
#   'popularity',
#   'flawless',
#   'blanc',
#   'flat',
#   'flavorful',
#   'spectacularly',
#   'ala',
#   'salary',
#   'layer',
#   'workplace',
#   'slam',
#   'relation',
#   'ambulance',
#   'later',
#   'complaint',
#   'glassy',
#   'lavish',
#   'solace',
#   'blackboard',
#   'unavailable',
#   'laughing',
#   'llama',
#   'lan',
#   'complain',
#   'playground',
#   'availability',
#   'similarly',
#   'palate',
#   'clarity',
#   'flame',
#   'plaza',
#   'launch',
#   'relative',
#   'classical',
#   'lantern',
#   'island',
#   'flamboyant',
#   'player',
#   'galaxy',
#   'flagship',
#   'lawn',
#   'palar',
#   'avalanche',
#   'bismillah',
#   'laid',
#   'explanation',
#   'uncontrollable',
#   'clap',
#   'similarity',
#   'population',
#   'lamp',
#   'plague',
#   'unexplainable',
#   'elaborate',
#   'labour',
#   'popularly',
#   'melange',
#   'cola',
#   'pillar',
#   'laughable',
#   'lark',
#   'halal',
#   'clandestine',
#   'isolated',
#   'disclaimer',
#   'planet',
#   'plantain',
#   'lackadaisical',
#   'claim',
#   'resemblance',
#   'language',
#   'esplanade',
#   'wallah',
#   'impala',
#   'flashy',
#   'dreamland',
#   'scintillate',
#   'laze',
#   'lam',
#   'relaunch',
#   'playa',
#   'gorilla',
#   'everlasting',
#   'gala',
#   'plant',
#   'salaam',
#   'blame',
#   'unpalatable',
#   'law',
#   'latitude',
#   'glacier',
#   'relationship',
#   'lager',
#   'lace',
#   'exemplary',
#   'escalator',
#   'stella'],
#  'ac': ['place',
#   'smack',
#   'back',
#   'terrace',
#   'shack',
#   'actually',
#   'lack',
#   'accessible',
#   'pack',
#   'spacious',
#   'mac',
#   'someplace',
#   'reach',
#   'gracious',
#   'satisfaction',
#   'macaroon',
#   'face',
#   'snack',
#   'actual',
#   'package',
#   'black',
#   'accord',
#   'stomach',
#   'spectacular',
#   'exactly',
#   'across',
#   'act',
#   'attractive',
#   'fact',
#   'space',
#   'compact',
#   'palace',
#   'peaceful',
#   'track',
#   'peace',
#   'accident',
#   'feedback',
#   'accidentally',
#   'accurate',
#   'access',
#   'facility',
#   'legacy',
#   'packet',
#   'headache',
#   'attract',
#   'factory',
#   'accept',
#   'bacon',
#   'oracle',
#   'pace',
#   'replacement',
#   'cockroach',
#   'acceptable',
#   'spinach',
#   'breacher',
#   'peach',
#   'attach',
#   'contact',
#   'approach',
#   'adjacent',
#   'capacity',
#   'abstract',
#   'accompaniment',
#   'grace',
#   'delicacy',
#   'spectacularly',
#   'accessibility',
#   'workplace',
#   'pistachio',
#   'accidental',
#   'smacking',
#   'crack',
#   'ache',
#   'zodiac',
#   'solace',
#   'blackboard',
#   'attraction',
#   'peacefully',
#   'race',
#   'accidently',
#   'throwback',
#   'knack',
#   'attack',
#   'account',
#   'factor',
#   'satisfactory',
#   'intact',
#   'vacation',
#   'interaction',
#   'beach',
#   'bracket',
#   'background',
#   'bachelor',
#   'accommodate',
#   'jack',
#   'reaction',
#   'disgrace',
#   'acronym',
#   'beacon',
#   'mackerel',
#   'lackadaisical',
#   'rack',
#   'sumac',
#   'facade',
#   'impact',
#   'transaction',
#   'acute',
#   'glacier',
#   'attached',
#   'active',
#   'teach',
#   'lace',
#   'machan',
#   'tacky',
#   'exact'],
#  'ce': ['place',
#   'nice',
#   'office',
#   'ambience',
#   'experience',
#   'decent',
#   'spice',
#   'price',
#   'since',
#   'excellent',
#   'service',
#   'terrace',
#   'ice',
#   'hence',
#   'thrice',
#   'juice',
#   'accessible',
#   'recently',
#   'rice',
#   'receive',
#   'concept',
#   'someplace',
#   'descent',
#   'decently',
#   'centrally',
#   'face',
#   'piece',
#   'difference',
#   'parcel',
#   'twice',
#   'introduce',
#   'central',
#   'celebration',
#   'choice',
#   'nicely',
#   'except',
#   'reduce',
#   'iceberg',
#   'entrance',
#   'preference',
#   'sauce',
#   'center',
#   'celebrate',
#   'certainly',
#   'experienced',
#   'space',
#   'chance',
#   'cancel',
#   'palace',
#   'inception',
#   'appearance',
#   'peaceful',
#   'certain',
#   'peace',
#   'balance',
#   'access',
#   'reliance',
#   'existence',
#   'necessary',
#   'advice',
#   'deceitful',
#   'recent',
#   'accept',
#   'received',
#   'glance',
#   'pace',
#   'replacement',
#   'notice',
#   'deceiving',
#   'acceptable',
#   'slice',
#   'exceptional',
#   'produce',
#   'tice',
#   'excess',
#   'essence',
#   'exceptionally',
#   'magnificent',
#   'adjacent',
#   'grace',
#   'accessibility',
#   'workplace',
#   'distance',
#   'convince',
#   'concern',
#   'ambulance',
#   'performance',
#   'chancery',
#   'vibrance',
#   'solace',
#   'conference',
#   'pice',
#   'justice',
#   'scene',
#   'peacefully',
#   'patience',
#   'crescent',
#   'race',
#   'vincent',
#   'centric',
#   'excelsior',
#   'dance',
#   'scenic',
#   'pronounce',
#   'successfully',
#   'suffice',
#   'influencer',
#   'indulgence',
#   'rejoice',
#   'force',
#   'process',
#   'convenience',
#   'lettuce',
#   'entice',
#   'dice',
#   'unnoticed',
#   'instance',
#   'reception',
#   'iced',
#   'maintenance',
#   'reminiscent',
#   'deceive',
#   'successful',
#   'disturbance',
#   'percent',
#   'masterpiece',
#   'cedar',
#   'alliance',
#   'concentrate',
#   'ceiling',
#   'reassurance',
#   'insistence',
#   'residence',
#   'disgrace',
#   'elegance',
#   'defence',
#   'resemblance',
#   'centaury',
#   'fragrance',
#   'dancer',
#   'abundance',
#   'ce',
#   'renaissance',
#   'eccentric',
#   'source',
#   'excessive',
#   'lace',
#   'sliced',
#   'science'],
#  '$d': ['dine',
#   'dinner',
#   'dont',
#   'decent',
#   'delicious',
#   'decide',
#   'dark',
#   'dosa',
#   'dear',
#   'dry',
#   'delivery',
#   'dragon',
#   'day',
#   'dole',
#   'dish',
#   'definitely',
#   'delightful',
#   'delegate',
#   'descent',
#   'dey',
#   'deliver',
#   'dum',
#   'dose',
#   'drink',
#   'different',
#   'decently',
#   'dessert',
#   'dirty',
#   'death',
#   'disappointed',
#   'degraded',
#   'de',
#   'die',
#   'damn',
#   'daily',
#   'dint',
#   'date',
#   'disappoint',
#   'desi',
#   'dip',
#   'difference',
#   'difficult',
#   'doubt',
#   'dirt',
#   'dev',
#   'da',
#   'double',
#   'diagonally',
#   'dining',
#   'dal',
#   'didnt',
#   'dim',
#   'despite',
#   'destination',
#   'decorate',
#   'doesnt',
#   'do',
#   'dog',
#   'disguise',
#   'diet',
#   'drab',
#   'dress',
#   'dingy',
#   'divide',
#   'dull',
#   'disgust',
#   'drunken',
#   'drop',
#   'drive',
#   'due',
#   'delay',
#   'describe',
#   'din',
#   'das',
#   'discover',
#   'disrespect',
#   'delight',
#   'duo',
#   'designer',
#   'dabba',
#   'daughter',
#   'decker',
#   'durbar',
#   'description',
#   'dun',
#   'dom',
#   'degree',
#   'decision',
#   'darling',
#   'duck',
#   'display',
#   'deceitful',
#   'doughnut',
#   'ditch',
#   'downside',
#   'default',
#   'dak',
#   'directly',
#   'dream',
#   'dial',
#   'degrade',
#   'disappointment',
#   'discovery',
#   'decorative',
#   'distinct',
#   'displayed',
#   'debit',
#   'dilli',
#   'diameter',
#   'deceiving',
#   'dive',
#   'deserve',
#   'delectable',
#   'dimly',
#   'drip',
#   'disgusting',
#   'dutch',
#   'disconnect',
#   'discussion',
#   'define',
#   'desire',
#   'duke',
#   'dairy',
#   'dodgy',
#   'dash',
#   'disc',
#   'deserted',
#   'disaster',
#   'deluxe',
#   'desert',
#   'dam',
#   'doctor',
#   'diner',
#   'dilemma',
#   'dangerously',
#   'deck',
#   'dad',
#   'diagonal',
#   'dis',
#   'design',
#   'deal',
#   'dusty',
#   'doubletree',
#   'divine',
#   'driving',
#   'dustbin',
#   'di',
#   'delicacy',
#   'drag',
#   'driven',
#   'door',
#   'div',
#   'desk',
#   'disastrous',
#   'distance',
#   'dick',
#   'dump',
#   'differently',
#   'deep',
#   'dependable',
#   'dig',
#   'disappointing',
#   'draw',
#   'dense',
#   'deeply',
#   'defunct',
#   'dipped',
#   'debate',
#   'dual',
#   'decoration',
#   'delightfully',
#   'definite',
#   'decline',
#   'drastically',
#   'discount',
#   'decade',
#   'dance',
#   'draught',
#   'ding',
#   'drunk',
#   'decant',
#   'dock',
#   'dumb',
#   'dumpling',
#   'decorated',
#   'deliciously',
#   'detail',
#   'denomination',
#   'duplicate',
#   'den',
#   'distribute',
#   'dead',
#   'dice',
#   'drumstick',
#   'disable',
#   'delighted',
#   'decimal',
#   'definition',
#   'dependably',
#   'dozen',
#   'decided',
#   'dislocate',
#   'dispatch',
#   'drizzle',
#   'deer',
#   'deceive',
#   'drew',
#   'decorum',
#   'duper',
#   'disturbance',
#   'displease',
#   'devil',
#   'donor',
#   'depend',
#   'dissatisfy',
#   'dolphin',
#   'downhill',
#   'dripping',
#   'decadent',
#   'disgrace',
#   'delusional',
#   'dust',
#   'disclaimer',
#   'destroy',
#   'dietary',
#   'defence',
#   'deviate',
#   'deplorable',
#   'daze',
#   'dang',
#   'doze',
#   'dome',
#   'dainty',
#   'doff',
#   'dental',
#   'dancer',
#   'dreamland',
#   'dockyard',
#   'dharani',
#   'donna',
#   'damage',
#   'dale',
#   'drinking',
#   'damp',
#   'distinguished',
#   'drool',
#   'disturbed',
#   'drawn',
#   'deadly',
#   'dynamic',
#   'dot',
#   'dare',
#   'diary',
#   'district',
#   'dashed',
#   'diverse',
#   'demand',
#   'discovered',
#   'druid',
#   'diamond',
#   'decathlon',
#   'dreamy',
#   'distinction',
#   'decrease'],
#  'di': ['dine',
#   'dinner',
#   'condition',
#   'medical',
#   'incredibly',
#   'dish',
#   'pending',
#   'reading',
#   'different',
#   'dirty',
#   'disappointed',
#   'traditional',
#   'die',
#   'dint',
#   'disappoint',
#   'dip',
#   'difference',
#   'difficult',
#   'dirt',
#   'paradise',
#   'addition',
#   'diagonally',
#   'dining',
#   'didnt',
#   'dim',
#   'disguise',
#   'diet',
#   'dingy',
#   'extraordinary',
#   'divide',
#   'disgust',
#   'edible',
#   'din',
#   'ordinary',
#   'discover',
#   'incredible',
#   'nandi',
#   'disrespect',
#   'outstanding',
#   'studio',
#   'display',
#   'ditch',
#   'directly',
#   'dial',
#   'disappointment',
#   'discovery',
#   'medium',
#   'sending',
#   'distinct',
#   'displayed',
#   'splendid',
#   'dilli',
#   'diameter',
#   'verdict',
#   'dive',
#   'addiction',
#   'dimly',
#   'disgusting',
#   'disconnect',
#   'discussion',
#   'disc',
#   'disaster',
#   'khadi',
#   'diner',
#   'dilemma',
#   'readily',
#   'diagonal',
#   'dis',
#   'grandiose',
#   'divine',
#   'di',
#   'pedicure',
#   'mediterranean',
#   'div',
#   'disastrous',
#   'building',
#   'conditionally',
#   'distance',
#   'inedible',
#   'dick',
#   'addicted',
#   'differently',
#   'pudding',
#   'dig',
#   'zodiac',
#   'disappointing',
#   'ridiculous',
#   'dipped',
#   'rendition',
#   'addict',
#   'discount',
#   'ding',
#   'holding',
#   'edit',
#   'podium',
#   'afterdinner',
#   'ridiculously',
#   'distribute',
#   'unwinding',
#   'spending',
#   'dice',
#   'disable',
#   'immediately',
#   'mediocre',
#   'dislocate',
#   'dispatch',
#   'leading',
#   'cordially',
#   'indigo',
#   'surroundings',
#   'disturbance',
#   'meridian',
#   'displease',
#   'cordial',
#   'dissatisfy',
#   'disgrace',
#   'disclaimer',
#   'dietary',
#   'tradition',
#   'idiot',
#   'outstandingly',
#   'predictably',
#   'misleading',
#   'medicine',
#   'subsidiary',
#   'distinguished',
#   'disturbed',
#   'radically',
#   'nomadic',
#   'diary',
#   'district',
#   'diverse',
#   'handicap',
#   'indicate',
#   'discovered',
#   'diamond',
#   'obsidian',
#   'radius',
#   'idiotic',
#   'distinction'],
#  'in': ['dine',
#   'dinner',
#   'thing',
#   'since',
#   'anything',
#   'international',
#   'main',
#   'everything',
#   'amazing',
#   'interior',
#   'point',
#   'tiny',
#   'nothing',
#   'vintage',
#   'mind',
#   'indeed',
#   'fascinate',
#   'sin',
#   'kind',
#   'joint',
#   'incredibly',
#   'something',
#   'rating',
#   'warning',
#   'seemingly',
#   'inside',
#   'think',
#   'definitely',
#   'interested',
#   'roving',
#   'continental',
#   'pending',
#   'mine',
#   'cuisine',
#   'find',
#   'amazingly',
#   'vicinity',
#   'rainy',
#   'evening',
#   'ring',
#   'king',
#   'fine',
#   'behind',
#   'reading',
#   'finger',
#   'instant',
#   'drink',
#   'engineering',
#   'engineering',
#   'morning',
#   'disappointed',
#   'passing',
#   'happiness',
#   'dint',
#   'disappoint',
#   'smelling',
#   'industrial',
#   'min',
#   'brain',
#   'parking',
#   'pine',
#   'cunning',
#   'cousin',
#   'chain',
#   'introduce',
#   'introduction',
#   'instantly',
#   'dining',
#   'dining',
#   'minute',
#   'industry',
#   'destination',
#   'thin',
#   'finally',
#   'adjoin',
#   'bring',
#   'combination',
#   'blessing',
#   'inch',
#   'treating',
#   'begin',
#   'plain',
#   'continuous',
#   'dingy',
#   'extraordinary',
#   'seminar',
#   'minimum',
#   'surprisingly',
#   'ginger',
#   'roaming',
#   'interesting',
#   'interesting',
#   'upcoming',
#   'mint',
#   'link',
#   'seating',
#   'instead',
#   'nominal',
#   'certainly',
#   'initially',
#   'quaint',
#   'remain',
#   'tiffin',
#   'spring',
#   'din',
#   'single',
#   'satisfying',
#   'singh',
#   'offering',
#   'ordinary',
#   'linnet',
#   'eating',
#   'inception',
#   'incredible',
#   'making',
#   'interloper',
#   'feeling',
#   'certain',
#   'within',
#   'inn',
#   'indulge',
#   'genuine',
#   'coziness',
#   'genuinely',
#   'seeing',
#   'business',
#   'hind',
#   'craving',
#   'outstanding',
#   'booking',
#   'opening',
#   'imagine',
#   'include',
#   'darling',
#   'invite',
#   'original',
#   'intend',
#   'stink',
#   'innovative',
#   'shopping',
#   'cheating',
#   'coincidentally',
#   'maintain',
#   'maintain',
#   'coming',
#   'disappointment',
#   'innovation',
#   'tasting',
#   'selling',
#   'heartbreaking',
#   'insanely',
#   'sending',
#   'interest',
#   'distinct',
#   'meeting',
#   'blink',
#   'inwards',
#   'smoking',
#   'incomplete',
#   'china',
#   'deceiving',
#   'cleanliness',
#   'sinful',
#   'waiting',
#   'disgusting',
#   'spinach',
#   'surprising',
#   'constraint',
#   'combine',
#   'line',
#   'minus',
#   'binge',
#   'incase',
#   'cumin',
#   'define',
#   'mainly',
#   'filling',
#   'timing',
#   'coloring',
#   'container',
#   'minimal',
#   'wine',
#   'minty',
#   'inexpensive',
#   'hearing',
#   'mains',
#   'protein',
#   'pin',
#   'trinity',
#   'inspire',
#   'remind',
#   'inauguration',
#   'diner',
#   'quintessential',
#   'explain',
#   'visiting',
#   'final',
#   'unimaginable',
#   'sunshine',
#   'greeting',
#   'shin',
#   'win',
#   'entertain',
#   'adjoining',
#   'adjoining',
#   'equinox',
#   'brewing',
#   'nine',
#   'divine',
#   'driving',
#   'dustbin',
#   'finish',
#   'increase',
#   'indoor',
#   'praline',
#   'running',
#   'train',
#   'sprinkle',
#   'kindly',
#   'matinee',
#   'melting',
#   'meaning',
#   'blowing',
#   'cooking',
#   'pineapple',
#   'building',
#   'ruin',
#   'inedible',
#   'indy',
#   'instruction',
#   'convince',
#   'smacking',
#   'serving',
#   'pudding',
#   'rainbow',
#   'originally',
#   'innate',
#   'gingery',
#   'jasmine',
#   'complaint',
#   'terrain',
#   'entrainment',
#   'lighting',
#   'appointment',
#   'bin',
#   'living',
#   'intersection',
#   'cinnamon',
#   'walking',
#   'disappointing',
#   'disappointing',
#   'interpretation',
#   'thanksgiving',
#   'laughing',
#   'grain',
#   'unwind',
#   'writing',
#   'pind',
#   'intelligent',
#   'unassuming',
#   'satin',
#   'excruciatingly',
#   'chin',
#   'complain',
#   'searching',
#   'intriguing',
#   'intriguing',
#   'mountain',
#   'sitting',
#   'rain',
#   'ging',
#   'infection',
#   'minion',
#   'mandarin',
#   'institution',
#   'trained',
#   'sirloin',
#   'wing',
#   'inconspicuous',
#   'retain',
#   'interview',
#   'gathering',
#   'inclusiveness',
#   'vincent',
#   'skin',
#   'definite',
#   'decline',
#   'tingler',
#   'bustling',
#   'blindly',
#   'welcoming',
#   'burning',
#   'watering',
#   'inform',
#   'ling',
#   'gin',
#   'setting',
#   'ding',
#   'quintessentially',
#   'holding',
#   'influencer',
#   'indulgence',
#   'winter',
#   'billing',
#   'infusion',
#   'virgin',
#   'initiative',
#   'sine',
#   'marinade',
#   'inner',
#   'dumpling',
#   'afterdinner',
#   'innovate',
#   'cabin',
#   'winner',
#   'denomination',
#   'insane',
#   'unsatisfying',
#   'pain',
#   'muffin',
#   'carrying',
#   'vino',
#   'working',
#   'unwinding',
#   'unwinding',
#   'spending',
#   'aint',
#   'grind',
#   'invariably',
#   'vitamin',
#   'hint',
#   'instance',
#   'pleasing',
#   'quint',
#   'maintenance',
#   'grapevine',
#   'juiciness',
#   'intact',
#   'tastiness',
#   'definition',
#   'wandering',
#   'intimate',
#   'citrine',
#   'invitation',
#   'prominent',
#   'interaction',
#   'easiness',
#   'window',
#   'convincing',
#   'convincing',
#   'missing',
#   'linch',
#   'inaugural',
#   'leading',
#   'rolling',
#   'unexplainable',
#   'reminiscent',
#   'predominantly',
#   'cleaning',
#   'information',
#   'wherein',
#   'opinion',
#   'infrastructure',
#   'rocking',
#   'indigo',
#   'stint',
#   'griffin',
#   'incorrect',
#   'surroundings',
#   'shockingly',
#   'paint',
#   'grainy',
#   'training',
#   'training',
#   'comforting',
#   'vinegar',
#   'beginning',
#   'beginning',
#   'housewarming',
#   'lightning',
#   'inconsistent',
#   'herein',
#   'culinary',
#   'shifting',
#   'astonishingly',
#   'terminus',
#   'exciting',
#   'inevitably',
#   'pink',
#   'ceiling',
#   'jingo',
#   'robin',
#   'dolphin',
#   'baking',
#   'bing',
#   'insistence',
#   'clandestine',
#   'pina',
#   'promising',
#   'dripping',
#   'string',
#   'aiming',
#   'stunning',
#   'insect',
#   'mein',
#   'ministry',
#   'weariness',
#   'lifeline',
#   'initial',
#   'institute',
#   'preopening',
#   'invest',
#   'origin',
#   'plantain',
#   'hanging',
#   'quinoa',
#   'inarguably',
#   'figurine',
#   'ginseng',
#   'crossing',
#   'dainty',
#   'smiling',
#   'marina',
#   'beguiling',
#   'swing',
#   'listening',
#   'marinate',
#   'outstandingly',
#   'injury',
#   'intention',
#   'wingless',
#   'sterling',
#   'eliminator',
#   'submarine',
#   'zamindar',
#   'wondering',
#   'stalling',
#   'mutiny',
#   'insider',
#   'scintillate',
#   'tamarind',
#   'pint',
#   'misleading',
#   'stuffing',
#   'guessing',
#   'loving',
#   'engineer',
#   'inferior',
#   'medicine',
#   'swarming',
#   'thinner',
#   'drinking',
#   'drinking',
#   'everlasting',
#   'ongoing',
#   'distinguished',
#   'innumerable',
#   'fascination',
#   'goldfinch',
#   'fishing',
#   'casino',
#   'inspired',
#   'intrigue',
#   'fountain',
#   'willing',
#   'bingo',
#   'pristine',
#   'insist',
#   'indicate',
#   'infinity',
#   'infinity',
#   'longing',
#   'fascinatingly',
#   'fascinatingly',
#   'spine',
#   'insufficient',
#   'refreshingly',
#   'rhino',
#   'distinction',
#   'enterprising',
#   'biting',
#   'incorrectly',
#   'captain',
#   'cocking',
#   'stingy',
#   'increasingly',
#   'increasingly',
#   'incomparably',
#   'valentine'],
#  'ne': ['dine',
#   'dinner',
#   'near',
#   'one',
#   'partner',
#   'need',
#   'honestly',
#   'unexpectedly',
#   'newly',
#   'money',
#   'new',
#   'nearby',
#   'alone',
#   'neer',
#   'next',
#   'never',
#   'bone',
#   'benne',
#   'everyone',
#   'neatly',
#   'corner',
#   'continental',
#   'mine',
#   'cuisine',
#   'stone',
#   'mane',
#   'fine',
#   'engineering',
#   'honest',
#   'hygiene',
#   'cone',
#   'happiness',
#   'chutney',
#   'negative',
#   'pine',
#   'energy',
#   'generally',
#   'goodness',
#   'neat',
#   'anyone',
#   'cleaner',
#   'neet',
#   'cane',
#   'plane',
#   'honey',
#   'unplanned',
#   'unexpected',
#   'madness',
#   'none',
#   'boneless',
#   'owner',
#   'someone',
#   'june',
#   'phone',
#   'panner',
#   'whenever',
#   'linnet',
#   'attentiveness',
#   'serene',
#   'designer',
#   'mundane',
#   'genuine',
#   'wellness',
#   'calmness',
#   'coziness',
#   'genuinely',
#   'business',
#   'generic',
#   'ness',
#   'neighborhood',
#   'necessary',
#   'imagine',
#   'ne',
#   'uneatable',
#   'nee',
#   'insanely',
#   'uneducated',
#   'zone',
#   'freshness',
#   'cuteness',
#   'manner',
#   'neither',
#   'generation',
#   'mannered',
#   'cleanliness',
#   'permanently',
#   'misfortune',
#   'connect',
#   'disconnect',
#   'sweetness',
#   'combine',
#   'line',
#   'define',
#   'container',
#   'wine',
#   'inexpensive',
#   'knew',
#   'fitness',
#   'foreigner',
#   'lane',
#   'stoner',
#   'diner',
#   'chimney',
#   'journey',
#   'channel',
#   'sunshine',
#   'nine',
#   'divine',
#   'tunnel',
#   'hurricane',
#   'needless',
#   'praline',
#   'mediterranean',
#   'matinee',
#   'generous',
#   'pineapple',
#   'brimstone',
#   'inedible',
#   'jasmine',
#   'richness',
#   'fortune',
#   'general',
#   'underneath',
#   'opener',
#   'scene',
#   'news',
#   'nonexistent',
#   'witness',
#   'trained',
#   'inclusiveness',
#   'decline',
#   'greenery',
#   'nearly',
#   'energetic',
#   'amnesia',
#   'sine',
#   'inner',
#   'afterdinner',
#   'winner',
#   'nerve',
#   'insane',
#   'spontaneously',
#   'confectioner',
#   'neck',
#   'benefit',
#   'turned',
#   'grapevine',
#   'juiciness',
#   'tastiness',
#   'citrine',
#   'prominent',
#   'ownership',
#   'unadorned',
#   'easiness',
#   'clone',
#   'unexplainable',
#   'renowned',
#   'vinegar',
#   'burner',
#   'inevitably',
#   'quietness',
#   'clandestine',
#   'panel',
#   'weariness',
#   'nectar',
#   'lifeline',
#   'neatness',
#   'neatness',
#   'planet',
#   'uniqueness',
#   'figurine',
#   'negotiate',
#   'submarine',
#   'needs',
#   'awesomeness',
#   'engineer',
#   'medicine',
#   'thinner',
#   'bene',
#   'stunner',
#   'pristine',
#   'runner',
#   'spine',
#   'oneself',
#   'uneasy',
#   'nearest',
#   'weakness',
#   'neighbor',
#   'network',
#   'valentine',
#   'nest'],
#  'nn': ['dinner',
#   'benne',
#   'anna',
#   'cunning',
#   'unplanned',
#   'mayonnaise',
#   'panner',
#   'linnet',
#   'inn',
#   'innovative',
#   'innovation',
#   'manner',
#   'mannered',
#   'connect',
#   'disconnect',
#   'sunny',
#   'channel',
#   'anniversary',
#   'tunnel',
#   'running',
#   'innate',
#   'penny',
#   'cinnamon',
#   'annoy',
#   'inner',
#   'afterdinner',
#   'innovate',
#   'winner',
#   'annual',
#   'funny',
#   'unnoticed',
#   'pannier',
#   'bunny',
#   'millennium',
#   'beginning',
#   'stunning',
#   'granny',
#   'donna',
#   'thinner',
#   'innumerable',
#   'stunner',
#   'runner'],
#  'er': ['dinner',
#   'platter',
#   'afternoon',
#   'experience',
#   'partner',
#   'otherwise',
#   'offer',
#   'proper',
#   'service',
#   'overwhelm',
#   'international',
#   'personally',
#   'terrace',
#   'cover',
#   'every',
#   'everything',
#   'eatery',
#   'order',
#   'interior',
#   'voucher',
#   'ordered',
#   'neer',
#   'never',
#   'ever',
#   'superb',
#   'super',
#   'saver',
#   'lover',
#   'delivery',
#   'timer',
#   'butter',
#   'overall',
#   'perfect',
#   'everyone',
#   'person',
#   'serve',
#   'prefer',
#   'corner',
#   'terrible',
#   'interested',
#   'goer',
#   'wer',
#   'southwestern',
#   'pepper',
#   'bakery',
#   'water',
#   'beer',
#   'baker',
#   'whopper',
#   'finger',
#   'deliver',
#   'properly',
#   'everybody',
#   'different',
#   'yesterday',
#   'consider',
#   'dessert',
#   'engineering',
#   'commercial',
#   'atmosphere',
#   'average',
#   'frequenter',
#   'allergic',
#   'conversation',
#   'cashier',
#   'several',
#   'however',
#   'imperial',
#   'per',
#   'number',
#   'watery',
#   'customer',
#   'zero',
#   'pizzeria',
#   'difference',
#   'energy',
#   'quarter',
#   'another',
#   'filter',
#   'generally',
#   'wonderful',
#   'peri',
#   'utter',
#   'cleaner',
#   'flower',
#   'literally',
#   'frazer',
#   'refer',
#   'anywhere',
#   'perfectly',
#   'iceberg',
#   'preference',
#   'wonder',
#   'cranberry',
#   'ginger',
#   'cheerful',
#   'center',
#   'powder',
#   'interesting',
#   'enter',
#   'waiter',
#   'strawberry',
#   'sheer',
#   'hunger',
#   'weather',
#   'overload',
#   'certainly',
#   'blueberry',
#   'experienced',
#   'owner',
#   'thirster',
#   'seriously',
#   'wheeler',
#   'version',
#   'murder',
#   'butterscotch',
#   'panner',
#   'eagerly',
#   'brewery',
#   'northern',
#   'offering',
#   'whenever',
#   'remember',
#   'better',
#   'discover',
#   'everyday',
#   'severe',
#   'turmeric',
#   'forever',
#   'werent',
#   'interloper',
#   'interloper',
#   'father',
#   'certain',
#   'serene',
#   'member',
#   'designer',
#   'either',
#   'convert',
#   'starter',
#   'daughter',
#   'rather',
#   'emergency',
#   'decker',
#   'counter',
#   'generic',
#   'eager',
#   'personal',
#   'beverage',
#   'understand',
#   'rocher',
#   'eastern',
#   'ponder',
#   'western',
#   'mealer',
#   'whether',
#   'whatever',
#   'paper',
#   'somewhere',
#   'cucumber',
#   'improper',
#   'user',
#   'mother',
#   'builder',
#   'register',
#   'discovery',
#   'whoever',
#   'bearer',
#   'berry',
#   'superior',
#   'together',
#   'modern',
#   'interest',
#   'potter',
#   'wander',
#   'matter',
#   'thrower',
#   'panther',
#   'clutter',
#   'chatter',
#   'diameter',
#   'manner',
#   'neither',
#   'snicker',
#   'verity',
#   'faster',
#   'tender',
#   'mere',
#   'sober',
#   'bitter',
#   'verdict',
#   'answer',
#   'shower',
#   'liver',
#   'generation',
#   'mannered',
#   'manager',
#   'property',
#   'spider',
#   'deserve',
#   'permanently',
#   'serenity',
#   'costumer',
#   'shocker',
#   'power',
#   'supper',
#   'advert',
#   'yesternight',
#   'utterly',
#   'breacher',
#   'container',
#   'carver',
#   'summer',
#   'versed',
#   'there',
#   'supermarket',
#   'watermelon',
#   'sucker',
#   'deserted',
#   'batter',
#   'disaster',
#   'moderate',
#   'foreigner',
#   'wherever',
#   'wherever',
#   'desert',
#   'filler',
#   'heritage',
#   'gallery',
#   'stoner',
#   'brother',
#   'buttercup',
#   'diner',
#   'cheater',
#   'mutter',
#   'sister',
#   'keralite',
#   'overly',
#   'dangerously',
#   'upper',
#   'numerous',
#   'exaggeration',
#   'premiere',
#   'theres',
#   'emerald',
#   'rubber',
#   'cheer',
#   'copper',
#   'lower',
#   'entertain',
#   'anniversary',
#   'outer',
#   'herbal',
#   'verdure',
#   'preferred',
#   'understatement',
#   'server',
#   'server',
#   'jaggery',
#   'raspberry',
#   'brassiere',
#   'mediterranean',
#   'carrier',
#   'layer',
#   'bewilder',
#   'tavern',
#   'generous',
#   'experiment',
#   'orderer',
#   'orderer',
#   'differently',
#   'serving',
#   'concern',
#   'mystery',
#   'appetizer',
#   'gingery',
#   'later',
#   'waster',
#   'elsewhere',
#   'performance',
#   'reserve',
#   'terrain',
#   'waver',
#   'silver',
#   'chancery',
#   'tiger',
#   'general',
#   'intersection',
#   'cooler',
#   'nursery',
#   'underground',
#   'underneath',
#   'conference',
#   'opener',
#   'interpretation',
#   'terrific',
#   'rocker',
#   'eater',
#   'er',
#   'proverb',
#   'erratic',
#   'suffer',
#   'rider',
#   'southern',
#   'bother',
#   'moreover',
#   'interview',
#   'admirer',
#   'amber',
#   'bootlegger',
#   'gather',
#   'gathering',
#   'counterfeit',
#   'therapy',
#   'encounter',
#   'period',
#   'preferable',
#   'tingler',
#   'external',
#   'patisserie',
#   'permit',
#   'alert',
#   'pitcher',
#   'watering',
#   'powerful',
#   'greenery',
#   'energetic',
#   'lobster',
#   'lantern',
#   'player',
#   'calmer',
#   'lighter',
#   'influencer',
#   'tower',
#   'winter',
#   'primavera',
#   'everywhere',
#   'everywhere',
#   'perry',
#   'imperium',
#   'monster',
#   'seer',
#   'inner',
#   'sherlock',
#   'overcrowd',
#   'afterdinner',
#   'afterdinner',
#   'supervisor',
#   'poster',
#   'winner',
#   'nerve',
#   'master',
#   'afterthought',
#   'premier',
#   'superbly',
#   'confectioner',
#   'opera',
#   'german',
#   'checker',
#   'nowhere',
#   'starer',
#   'longer',
#   'sticker',
#   'contender',
#   'pannier',
#   'herd',
#   'buttery',
#   'hereafter',
#   'hereafter',
#   'reservation',
#   'lesser',
#   'wandering',
#   'university',
#   'membership',
#   'vera',
#   'wonderfully',
#   'operate',
#   'interaction',
#   'ownership',
#   'pepperoni',
#   'leftover',
#   'miserable',
#   'cashmere',
#   'butterfly',
#   'wherein',
#   'fiery',
#   'deer',
#   'duper',
#   'perhaps',
#   'overcome',
#   'operational',
# ...
#   'deceitful',
#   'received',
#   'weird',
#   'neither',
#   'deceiving',
#   'weirdly',
#   'protein',
#   'foreigner',
#   'foreign',
#   'eight',
#   'counterfeit',
#   'albeit',
#   'wherein',
#   'deceive',
#   'herein',
#   'ceiling',
#   'mein',
#   'leisure',
#   'neighbor'],
#  'pt': ['option',
#   'concept',
#   'scrumptious',
#   'assumption',
#   'prompt',
#   'except',
#   'sumptuous',
#   'inception',
#   'apt',
#   'description',
#   'accept',
#   'optimal',
#   'acceptable',
#   'skeptical',
#   'empty',
#   'exceptional',
#   'capture',
#   'exceptionally',
#   'attempt',
#   'impromptu',
#   'opt',
#   'uptown',
#   'tempt',
#   'aptly',
#   'kept',
#   'reception',
#   'promptly',
#   'nondescript',
#   'chapter',
#   'subscription',
#   'septate',
#   'adopt',
#   'captain'],
#  'ix': ['mixed', 'mix', 'phoenix', 'fix', 'six', 'fixed', 'mixture', 'sixth'],
#  'xe': ['mixed',
#   'relaxed',
#   'executive',
#   'deluxe',
#   'fixed',
#   'execute',
#   'exemplary'],
#  'ox': ['box',
#   'orthodox',
#   'equinox',
#   'cakebox',
#   'proximity',
#   'moxa',
#   'fox',
#   'jukebox',
#   'foxtail',
#   'approximately',
#   'antioxidant',
#   'paradox'],
#  'sk': ['basket',
#   'ask',
#   'risk',
#   'kiosk',
#   'flask',
#   'skeptical',
#   'whiskey',
#   'whisk',
#   'task',
#   'skip',
#   'desk',
#   'sky',
#   'skin',
#   'skilled',
#   'risky'],
#  'rf': ['perfect',
#   'wonderful',
#   'perfectly',
#   'cheerful',
#   'colorful',
#   'flavorful',
#   'performance',
#   'counterfeit',
#   'powerful',
#   'bearfoot',
#   'wonderfully',
#   'butterfly',
#   'perfection'],
#  'pu': ['puff',
#   'pure',
#   'popular',
#   'put',
#   'pub',
#   'purely',
#   'pulpy',
#   'pungent',
#   'puma',
#   'pump',
#   'punch',
#   'pull',
#   'campus',
#   'popularity',
#   'opus',
#   'purpose',
#   'purchase',
#   'pudding',
#   'purposefully',
#   'puja',
#   'pun',
#   'republic',
#   'putt',
#   'public',
#   'reputed',
#   'puffed',
#   'pulp',
#   'population',
#   'putty',
#   'popularly',
#   'purple',
#   'purse',
#   'impulse',
#   'push',
#   'output',
#   'pulka',
#   'reputation',
#   'repute'],
#  'rl': ['regularly',
#   'properly',
#   'early',
#   'sugarless',
#   'world',
#   'particularly',
#   'garlic',
#   'overload',
#   'starlite',
#   'eagerly',
#   'interloper',
#   'fairly',
#   'darling',
#   'parlor',
#   'utterly',
#   'swirl',
#   'overly',
#   'pearl',
#   'clearly',
#   'spectacularly',
#   'poorly',
#   'sirloin',
#   'similarly',
#   'nearly',
#   'sherlock',
#   'girl',
#   'popularly',
#   'formerly',
#   'sterling',
#   'everlasting',
#   'barley'],
#  'yo': ['everyone',
#   'anyone',
#   'young',
#   'layout',
#   'yo',
#   'mayonnaise',
#   'youve',
#   'tryout',
#   'youd',
#   'joyous',
#   'beyond',
#   'york',
#   'yoga'],
#  'ms': ['clumsy', 'brimstone', 'flimsy', 'drumstick'],
#  'gi': ['give',
#   'region',
#   'magic',
#   'engineering',
#   'allergic',
#   'hygiene',
#   'hygienic',
#   'begin',
#   'ginger',
#   'nostalgic',
#   'gid',
#   'imagine',
#   'nostalgia',
#   'original',
#   'register',
#   'gift',
#   'strategically',
#   'unhygienic',
#   'unimaginable',
#   'regional',
#   'legit',
#   'originally',
#   'gingery',
#   'thanksgiving',
#   'tragic',
#   'ging',
#   'gin',
#   'virgin',
#   'girl',
#   'forgive',
#   'gig',
#   'magical',
#   'beginning',
#   'magician',
#   'origin',
#   'hanging',
#   'ginseng',
#   'hygienically',
#   'fungi',
#   'engineer',
#   'vigil',
#   'longing',
#   'aegis'],
#  'tw': ['two',
#   'twice',
#   'twas',
#   'twist',
#   'twisted',
#   'twenty',
#   'twilight',
#   'twisty',
#   'trustworthy',
#   'network'],
#  'tc': ['kitchen',
#   'stretch',
#   'catch',
#   'butterscotch',
#   'ditch',
#   'match',
#   'catchy',
#   'dutch',
#   'watch',
#   'catchup',
#   'pitcher',
#   'notch',
#   'chitchat',
#   'cultch',
#   'hotch',
#   'ketchup',
#   'dispatch',
#   'litchi',
#   'switch',
#   'batch',
#   'unmatched',
#   'hatch',
#   'scotch'],
#  'sn': ['wasnt', 'snack', 'doesnt', 'snicker', 'snap', 'snow', 'snake'],
#  'rm': ['normal',
#   'platform',
#   'karma',
#   'warm',
#   'charm',
#   'turmeric',
#   'farm',
#   'form',
#   'confirm',
#   'permanently',
#   'gourmet',
#   'supermarket',
#   'watermelon',
#   'performance',
#   'norm',
#   'normally',
#   'permit',
#   'inform',
#   'warmth',
#   'farmhouse',
#   'german',
#   'information',
#   'housewarming',
#   'terminus',
#   'uniform',
#   'formerly',
#   'buttermilk',
#   'swarming',
#   'formal',
#   'army',
#   'arm'],
#  'gl': ['seemingly',
#   'amazingly',
#   'eggless',
#   'bugle',
#   'surprisingly',
#   'single',
#   'glory',
#   'glad',
#   'glaze',
#   'strongly',
#   'glance',
#   'eagle',
#   'glass',
#   'struggle',
#   'jungle',
#   'global',
#   'glen',
#   'gluten',
#   'glassy',
#   'excruciatingly',
#   'tingler',
#   'glimpse',
#   'globe',
#   'gloomy',
#   'shockingly',
#   'triangle',
#   'astonishingly',
#   'igloo',
#   'ugly',
#   'outstandingly',
#   'wingless',
#   'glacier',
#   'fascinatingly',
#   'refreshingly',
#   'increasingly'],
#  'nv': ['convenient',
#   'conversation',
#   'environment',
#   'convert',
#   'invite',
#   'conveniently',
#   'convince',
#   'convenience',
#   'invariably',
#   'invitation',
#   'convincing',
#   'invest',
#   'conventional'],
#  'ef': ['prefer',
#   'definitely',
#   'careful',
#   'belief',
#   'refresh',
#   'refer',
#   'preference',
#   'effort',
#   'peaceful',
#   'chef',
#   'default',
#   'refund',
#   'beef',
#   'define',
#   'effective',
#   'efficient',
#   'tasteful',
#   'preferred',
#   'purposefully',
#   'peacefully',
#   'briefly',
#   'defunct',
#   'definite',
#   'preferable',
#   'prefect',
#   'theft',
#   'benefit',
#   'refreshment',
#   'definition',
#   'leftover',
#   'defence',
#   'tastefully',
#   'preferably',
#   'left',
#   'hopefully',
#   'brief',
#   'reflect',
#   'refreshingly'],
#  'hy': ['healthy',
#   'hygiene',
#   'hygienic',
#   'worthy',
#   'praiseworthy',
#   'heathy',
#   'catchy',
#   'crunchy',
#   'thyme',
#   'unhygienic',
#   'earthy',
#   'unhealthy',
#   'swathy',
#   'thy',
#   'flashy',
#   'hygienically',
#   'trustworthy'],
#  'wn': ['known',
#   'town',
#   'brownie',
#   'prawn',
#   'owner',
#   'brown',
#   'downside',
#   'crown',
#   'uptown',
#   'thrown',
#   'lawn',
#   'ownership',
#   'renowned',
#   'unknown',
#   'downhill',
#   'drawn',
#   'spawn'],
#  'tm': ['apartment',
#   'atmosphere',
#   'commitment',
#   'disappointment',
#   'utmost',
#   'treatment',
#   'compartment',
#   'appointment',
#   'nightmare',
#   'batman',
#   'oatmeal',
#   'sweetmeat',
#   'assortment'],
#  'bs': ['absolutely',
#   'absolute',
#   'obsession',
#   'abstract',
#   'obsolete',
#   'lobster',
#   'substandard',
#   'subscription',
#   'subsidiary',
#   'obsidian'],
#  'gg': ['egg',
#   'eggless',
#   'suggest',
#   'suggestable',
#   'soggy',
#   'struggle',
#   'exaggeration',
#   'jaggery',
#   'bootlegger',
#   'suggestion',
#   'exaggerate',
#   'buggy',
#   'saggy'],
#  'oe': ['goer',
#   'joe',
#   'doesnt',
#   'phoenix',
#   'whoever',
#   'amoeba',
#   'aloe',
#   'poetry'],
#  'ls': ['also',
#   'else',
#   'false',
#   'elsewhere',
#   'poolside',
#   'excelsior',
#   'bowls',
#   'whilst',
#   'impulse',
#   'tulsi'],
#  'hw': ['southwestern', 'southwest', 'highway'],
#  'du': ['fraudulent',
#   'dum',
#   'industrial',
#   'introduce',
#   'introduction',
#   'industry',
#   'reduce',
#   'dull',
#   'fondue',
#   'due',
#   'duo',
#   'indulge',
#   'durbar',
#   'dun',
#   'duck',
#   'uneducated',
#   'dutch',
#   'product',
#   'duke',
#   'produce',
#   'dusty',
#   'verdure',
#   'dustbin',
#   'dump',
#   'dual',
#   'indulgence',
#   'dumb',
#   'dumpling',
#   'chandu',
#   'duplicate',
#   'roundup',
#   'duper',
#   'dust',
#   'overdue'],
#  'bv': ['obviously'],
#  'tf': ['delightful',
#   'platform',
#   'thoughtful',
#   'deceitful',
#   'potful',
#   'outfit',
#   'delightfully',
#   'forgetful'],
#  'sf': ['satisfy',
#   'satisfaction',
#   'unsatisfied',
#   'satisfied',
#   'satisfying',
#   'blissful',
#   'misfortune',
#   'blissfully',
#   'successfully',
#   'unsatisfying',
#   'satisfactory',
#   'successful',
#   'dissatisfy'],
#  'ga': ['sugar',
#   'delegate',
#   'extravagant',
#   'negative',
#   'sugarless',
#   'elegant',
#   'agarwal',
#   'garlic',
#   'game',
#   'brigade',
#   'garden',
#   'gang',
#   'bungalow',
#   'legacy',
#   'gaud',
#   'organic',
#   'arrogant',
#   'gallery',
#   'garage',
#   'engage',
#   'ganga',
#   'ganga',
#   'organized',
#   'organize',
#   'gate',
#   'regard',
#   'gap',
#   'rogan',
#   'gateway',
#   'margarita',
#   'gather',
#   'gathering',
#   'sugary',
#   'galaxy',
#   'regale',
#   'naga',
#   'garbage',
#   'extravaganza',
#   'gallop',
#   'vinegar',
#   'elegance',
#   'gas',
#   'yoga',
#   'banga',
#   'elegantly',
#   'gala',
#   'hangar',
#   'organization',
#   'gastronomic',
#   'gali'],
#  'og': ['hog',
#   'dog',
#   'jog',
#   'together',
#   'soggy',
#   'nitrogen',
#   'arrogant',
#   'rogue',
#   'recognition',
#   'bogo',
#   'rogan',
#   'kilogram',
#   'yoga',
#   'fog',
#   'program'],
#  'kf': ['breakfast', 'thankful', 'thankfully'],
#  'wd': ['crowd', 'powder', 'crowded', 'overcrowd', 'crowdy', 'rowdy'],
#  'rg': ['large',
#   'urge',
#   'allergic',
#   'energy',
#   'target',
#   'iceberg',
#   'forget',
#   'emergency',
#   'charge',
#   'burg',
#   'organic',
#   'gorgeous',
#   'organized',
#   'organize',
#   'underground',
#   'margarita',
#   'energetic',
#   'virgin',
#   'gorge',
#   'forgot',
#   'forgive',
#   'forgetful',
#   'inarguably',
#   'urgent',
#   'forgotten',
#   'evergreen',
#   'organization',
#   'merge',
#   'unarguably'],
#  'rc': ['search',
#   'commercial',
#   'scarcity',
#   'parcel',
#   'circle',
#   'research',
#   'charcoal',
#   'church',
#   'bawarchi',
#   'orchard',
#   'buttercup',
#   'purchase',
#   'orchid',
#   'monarch',
#   'searching',
#   'force',
#   'staircase',
#   'overcrowd',
#   'arcade',
#   'overcome',
#   'percent',
#   'scorch',
#   'circus',
#   'march',
#   'source',
#   'uppercut'],
#  'hl': ['highly',
#   'worthless',
#   'freshly',
#   'thoroughly',
#   'speechless',
#   'monthly',
#   'highlight',
#   'decathlon'],
#  'wf': ['awful', 'awfully'],
#  'eh': ['behind',
#   'behavior',
#   'behaviour',
#   'somehow',
#   'behalf',
#   'bakehouse',
#   'behave',
#   'apprehensive',
#   'firehouse',
#   'comprehensive'],
#  'sr': ['sri', 'disrespect'],
#  'gn': ['signal',
#   'ignore',
#   'signature',
#   'designer',
#   'magnum',
#   'foreigner',
#   'magnificent',
#   'design',
#   'recognition',
#   'foreign',
#   'ignorant',
#   'magnolia',
#   'significant'],
#  'pd': ['update'],
#  'lv': ['velvet', 'silver', 'resolve', 'solve'],
#  'dg': ['budget',
#   'judge',
#   'fudge',
#   'bridge',
#   'dodgy',
#   'edge',
#   'fudgy',
#   'knowledge'],
#  'dh': ['childhood', 'roadhouse', 'dharani'],
#  'iq': ['unique', 'liquor', 'liquid', 'uniquely', 'antique', 'uniqueness'],
#  'mn': ['damn', 'calmness', 'chimney', 'amnesia'],
#  'yg': ['hygiene', 'hygienic', 'unhygienic', 'playground', 'hygienically'],
#  'nu': ['menu',
#   'number',
#   'minute',
#   'coconut',
#   'continuous',
#   'nutritious',
#   'venue',
#   'genuine',
#   'magnum',
#   'genuinely',
#   'walnut',
#   'doughnut',
#   'hazelnut',
#   'nuclear',
#   'minus',
#   'numerous',
#   'nutty',
#   'nursery',
#   'unusual',
#   'avenue',
#   'peanut',
#   'annual',
#   'nutrition',
#   'chestnut',
#   'nut',
#   'terminus',
#   'nun',
#   'innumerable'],
#  '$z': ['zero',
#   'z',
#   'zone',
#   'zoo',
#   'zodiac',
#   'zee',
#   'zed',
#   'zest',
#   'zamindar'],
#  'uy': ['buy', 'guy'],
#  'xq': ['exquisite'],
#  'eb': ['kebab',
#   'celebration',
#   'iceberg',
#   'celebrate',
#   'blueberry',
#   'debit',
#   'cakebox',
#   'debate',
#   'somebody',
#   'amoeba',
#   'jukebox',
#   'notebook',
#   'hereby',
#   'keb'],
#  'gy': ['energy',
#   'dingy',
#   'soggy',
#   'gym',
#   'dodgy',
#   'tangy',
#   'fudgy',
#   'buggy',
#   'saggy',
#   'stingy'],
#  'ae': ['aesthetic', 'sundae', 'bae', 'aesthetically', 'aegis'],
#  'nf': ['unfortunately',
#   'confusion',
#   'confirm',
#   'sinful',
#   'fanfare',
#   'confuse',
#   'conference',
#   'infection',
#   'inform',
#   'influencer',
#   'infusion',
#   'confused',
#   'confectioner',
#   'information',
#   'infrastructure',
#   'spoonful',
#   'inferior',
#   'unfair',
#   'unfriendly',
#   'infinity'],
#  'aj': ['maharaja',
#   'majestic',
#   'raj',
#   'major',
#   'taj',
#   'cajun',
#   'raja',
#   'khaja',
#   'majority'],
#  'ja': ['maharaja',
#   'jar',
#   'jail',
#   'jam',
#   'jade',
#   'adjacent',
#   'jaggery',
#   'raja',
#   'jasmine',
#   'japan',
#   'puja',
#   'khaja',
#   'jaw',
#   'jack',
#   'jazzy',
#   'jazz',
#   'jaunt',
#   'jay',
#   'jawab'],
#  'dj': ['adjoin', 'adjacent', 'adjoining', 'adjustable'],
#  'hd': ['birthday'],
#  'sg': ['disguise', 'disgust', 'disgusting', 'thanksgiving', 'disgrace'],
#  'kk': ['tikka'],
#  'bw': ['subway'],
#  'uz': ['buzz', 'buzzy'],
#  'sq': ['mosque',
#   'squid',
#   'squad',
#   'squirrel',
#   'square',
#   'picturesque',
#   'arabesque'],
#  'yw': ['anywhere', 'everywhere'],
#  'nq': ['enquiry', 'unquestionably', 'enquire'],
#  'fg': ['afghani'],
#  'oj': ['mojo', 'sojourn'],
#  '$x': ['x'],
#  'uo': ['continuous', 'sumptuous', 'duo', 'liquor', 'inconspicuous'],
#  'ao': ['extraordinary', 'chaos', 'tao'],
#  'xa': ['exactly',
#   'example',
#   'exaggeration',
#   'moxa',
#   'exam',
#   'exaggerate',
#   'exact'],
#  'np': ['unplanned',
#   'unprofessional',
#   'unplug',
#   'unpretentious',
#   'nonprofit',
#   'unpolite',
#   'unprofessionalism',
#   'unpalatable'],
#  'bz': ['sabzi'],
#  'rp': ['surprisingly',
#   'surprise',
#   'corporate',
#   'burp',
#   'surprising',
#   'airport',
#   'purpose',
#   'purposefully',
#   'interpretation',
#   'sharp',
#   'corporation',
#   'masterpiece',
#   'purple',
#   'underpass',
#   'enterprising'],
#  'nb': ['cranberry',
#   'unbelievably',
#   'unbelievable',
#   'rainbow',
#   'unbeatable',
#   'bonbon'],
#  'kr': ['kraft', 'cockroach', 'okra', 'prakriti'],
#  'pc': ['upcoming', 'popcorn', 'cupcake'],
#  'zl': ['sizzle', 'drizzle'],
#  'lg': ['nostalgic', 'indulge', 'nostalgia', 'indulgence'],
#  'dv': ['adventurous', 'advice', 'advert', 'unadventurous', 'advise'],
#  'wb': ['strawberry', 'throwback'],
#  'kl': ['pickle',
#   'frankly',
#   'weekly',
#   'quickly',
#   'folklore',
#   'sprinkle',
#   'tickle'],
#  'rh': ['rhe', 'neighborhood', 'perhaps', 'rhino'],
#  'lp': ['helpful', 'help', 'pulpy', 'alpha', 'pulp', 'gulp', 'dolphin'],
#  'pf': ['helpful'],
#  'dc': ['godchild'],
#  'ps': ['upset',
#   'capsicum',
#   'upstairs',
#   'tipsy',
#   'glimpse',
#   'upscale',
#   'perhaps',
#   'chopstick'],
#  'lr': ['already', 'alright'],
#  'oh': ['poha', 'soho', 'oh', 'alcohol', 'boho', 'alcoholic', 'woohoo'],
#  'yi': ['satisfying', 'unsatisfying', 'carrying'],
#  'ml': ['randomly', 'dimly', 'dreamland'],
#  'df': ['handful', 'goldfinch'],
#  'ax': ['relaxed', 'relax', 'axis', 'tax', 'taxi', 'galaxy'],
#  'yr': ['yr', 'syrup', 'theyre', 'tyre'],
#  'yn': ['synonymous', 'sync', 'dynamic'],
#  'aa': ['baa', 'bazaar', 'naam', 'baar', 'aa', 'salaam'],
#  'yd': ['everyday', 'payday'],
#  'nm': ['environment', 'entrainment', 'cantonment', 'unmatched', 'unmanaged'],
#  'ku': ['pickup', 'kudos', 'kung', 'kusum'],
#  'yx': ['onyx'],
#  'ln': ['wellness', 'walnut', 'hazelnut'],
#  'bb': ['shabby',
#   'dabba',
#   'bubble',
#   'gobble',
#   'rubbish',
#   'rubber',
#   'lobby',
#   'stubborn',
#   'cabbage',
#   'hubby',
#   'rubbery'],
#  'db': ['feedback', 'cardboard'],
#  'hb': ['neighborhood', 'neighbor'],
#  'xi': ['axis',
#   'existence',
#   'taxi',
#   'proximity',
#   'nonexistent',
#   'approximately',
#   'exist',
#   'antioxidant'],
#  'uv': ['youve'],
#  'hf': ['mouthful'],
#  'hn': ['doughnut', 'freshness', 'richness'],
#  'tb': ['heartbreaking', 'dustbin', 'football'],
#  'ez': ['breezy', 'freeze', 'breeze'],
#  'zo': ['zone', 'zoo', 'zodiac'],
#  'nr': ['unresponsive', 'unreliable', 'unrecommendable', 'sunrise', 'unreal'],
#  'sb': ['husband'],
#  'lc': ['alcohol', 'alchemy', 'balcony', 'welcome', 'welcoming', 'alcoholic'],
#  'ux': ['luxury', 'deluxe', 'luxurious'],
#  'xu': ['luxury', 'luxurious'],
#  'kh': ['khan', 'khadi', 'khaja', 'akhrot'],
#  'ko': ['kori', 'lookout', 'kor', 'ko', 'kora', 'workout'],
#  'uk': ['duke', 'fluke', 'jukebox'],
#  'tk': ['matka'],
#  'iw': ['kiwi'],
#  'eu': ['queue', 'museum', 'amateurish'],
#  'gs': ['amongst', 'alongside', 'flagship', 'surroundings'],
#  'yc': ['cycle', 'bicycle'],
#  'kt': ['cocktail', 'shakti'],
#  'rz': ['marzipan'],
#  'nh': ['unhygienic', 'unhealthy', 'unhappy', 'downhill'],
#  'dm': ['landmark', 'handmade', 'admirer', 'admit'],
#  'pg': ['upgrade'],
#  'pb': ['upbeat', 'raspberry'],
#  'lb': ['bulb', 'alba', 'albeit'],
#  'bh': ['bhara'],
#  'kp': ['workplace'],
#  'wy': ['chewy'],
#  'ej': ['reject', 'rejoice'],
#  'kb': ['blackboard'],
#  'ws': ['news', 'browse'],
#  'uj': ['puja'],
#  'kw': ['walkway', 'oakwood'],
#  'mt': ['warmth'],
#  'mz': ['hamza'],
#  'xy': ['galaxy', 'sexy'],
#  'aq': ['aqua'],
#  'mh': ['farmhouse'],
#  'dk': ['vodka'],
#  'hm': ['refreshment', 'establishment', 'cashmere'],
#  'gt': ['length'],
#  'nz': ['extravaganza'],
#  'kg': ['background'],
#  'wu': ['swung', 'wud'],
#  'wk': ['chowk'],
#  'km': ['bookmark'],
#  'cs': ['electronics'],
#  'ji': ['jingo'],
#  'xh': ['exhaust', 'exhibition'],
#  'rq': ['cirque'],
#  'bm': ['submarine'],
#  'rj': ['arjun'],
#  'fs': ['offshoot'],
#  'gf': ['mugful'],
#  'tv': ['tattva'],
#  'mc': ['amchoor'],
#  'tp': ['output'],
#  'mr': ['amrita']}

# %% [markdown]
# ## INVERTED INDEX WITH POSITIONAL INFORMATION

# %%
new_list = []
for i in range(dataframe.shape[0]):
    count = 0
    for j in dataframe.iloc[i,1].split():
        new_list.append([j,i,count])
        count+=1
new_list = sorted(new_list)
dict_index = {}
words = []
for i in new_list:
    if i[0] not in words:
        words.append(i[0])
        dict_index[i[0]] = [1,{i[1]:[i[2]]}]
    else:
        if i[1] not in dict_index[i[0]][1]:            
            dict_index[i[0]][0]+=1
            dict_index[i[0]][1][i[1]] = [i[2]]
        else:
            dict_index[i[0]][1][i[1]].append(i[2])
print(dict_index)

# %%
#when positional information is included
#dict_index is a dictionary structure
#each word is a key
#The value of each word is a list where first element is document frequency and 
#second element is a dictionary with doc id as key and positional info as a list
